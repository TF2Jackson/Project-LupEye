# %%
#!/usr/bin/env python
# coding: utf-8

# In[2]:


CONSUMER_KEY = 'a19MLVL0NMt7ByLp74Ey0hFN7'
CONSUMER_KEY_SECRET = 'q2KiIFKpwoLqXIIOjNAZ4zEm8h9Vmvwp8X3drcr0WeiLepdJYt'
ACCESS_TOKEN = '1167467648181035008-8PqoqisYZTNwAHxvmd6QqYmH2ztS6a'
ACCESS_TOKEN_SECRET = 'FnXJhL4a50kSTb5Bzr1Ix6cIfnXG6XxvrAPtPU7gmiyal'

import tweepy
import csv
from textblob import TextBlob

auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_KEY_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)

csvFile = open('#freetommy.csv', 'a')
csvWriter = csv.writer(csvFile)

for tweet in tweepy.Cursor(api.search, q="#freetommy",  count=100000,
                                lang="en",
                                since_id=2019 - 10 - 17).items():
        print(tweet.created_at, tweet.text)
        analysis = TextBlob(tweet.text)
        print(analysis.sentiment_assessments)
        csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8'), analysis.polarity, analysis.subjectivity])


# In[ ]:
# Out:
# 2020-02-07 01:27:03 RT @keepingupw_ashh: Laylay 💕 my twin fr  #FREETOMMY
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-07 01:26:41 Laylay 💕 my twin fr  #FREETOMMY https://t.co/EuczBh8isW
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-06 22:43:42 @LavenderRare #freetommy
# My petition will get like 21 signatures you'll see, then you will be banned. It's what I,… https://t.co/BRY2C9m43j
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-06 22:40:02 @LavenderRare I'm offended by this, you needing to know who I am. That's it, I'm making a petition to ban your twit… https://t.co/9XBV8njh0U
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-06 07:04:18 RT @Suzieiswright: When the establishment in you country protects grooming gangs.  When the police in your country arrest a voice speaking…
# Sentiment(polarity=-0.05, subjectivity=0.0, assessments=[(['arrest'], -0.05, 0.0, None)])
# 2020-02-06 05:48:20 RT @Suzieiswright: When the establishment in you country protects grooming gangs.  When the police in your country arrest a voice speaking…
# Sentiment(polarity=-0.05, subjectivity=0.0, assessments=[(['arrest'], -0.05, 0.0, None)])
# 2020-02-05 22:37:03 RT @Centre_newz: PLEASE SHARE FAR AND WIDE!!! here is @RealDannyTommo liaising with the @metpoliceuk asking them why they are letting maske…
# Sentiment(polarity=-0.04765625, subjectivity=0.7, assessments=[(['far'], 0.1, 1.0, None), (['wide', '!', '!', '!'], -0.1953125, 0.4, None)])
# 2020-02-05 08:52:07 RT @Adm_deRuyter: @TomWho4 We will not be gagged anymore @geertwilderspvv 9 June 2018 #FreeTommy https://t.co/y8QXvis2bB
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-05 08:45:30 RT @Adm_deRuyter: @TomWho4 We will not be gagged anymore @geertwilderspvv 9 June 2018 #FreeTommy https://t.co/y8QXvis2bB
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-05 07:47:45 RT @ARmastrangelo: Tommy Robinson has been arrested and jailed for 13 months for reporting on child grooming gangs.
#
# The UK has made it ill…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-05 07:11:01 RT @Centre_newz: PLEASE SHARE FAR AND WIDE!!! here is @RealDannyTommo liaising with the @metpoliceuk asking them why they are letting maske…
# Sentiment(polarity=-0.04765625, subjectivity=0.7, assessments=[(['far'], 0.1, 1.0, None), (['wide', '!', '!', '!'], -0.1953125, 0.4, None)])
# 2020-02-04 23:24:59 @TomWho4 We will not be gagged anymore @geertwilderspvv 9 June 2018 #FreeTommy https://t.co/y8QXvis2bB
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-04 18:42:07 @danpfeiffer @TVietor08 @jonlovett @jonfavs Is that the pecking order at @PodSaveAmerica ? #FreeTommy
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-03 10:16:30 RT @Wordofbeak: @LBC @MaajidNawaz Why didn’t YOU listen to Tommy Robinson, Maajid? YOU didn’t even have to fear being regarded as racist, d…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-02 23:24:28 RT @Wordofbeak: @LBC @MaajidNawaz Why didn’t YOU listen to Tommy Robinson, Maajid? YOU didn’t even have to fear being regarded as racist, d…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-02 20:01:20 RT @Wordofbeak: @LBC @MaajidNawaz Why didn’t YOU listen to Tommy Robinson, Maajid? YOU didn’t even have to fear being regarded as racist, d…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-02 19:29:44 RT @Wordofbeak: @LBC @MaajidNawaz Why didn’t YOU listen to Tommy Robinson, Maajid? YOU didn’t even have to fear being regarded as racist, d…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-02 18:37:58 RT @Wordofbeak: @LBC @MaajidNawaz Why didn’t YOU listen to Tommy Robinson, Maajid? YOU didn’t even have to fear being regarded as racist, d…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-02 18:32:07 RT @Wordofbeak: @LBC @MaajidNawaz Why didn’t YOU listen to Tommy Robinson, Maajid? YOU didn’t even have to fear being regarded as racist, d…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-02 18:18:51 RT @Wordofbeak: @LBC @MaajidNawaz Why didn’t YOU listen to Tommy Robinson, Maajid? YOU didn’t even have to fear being regarded as racist, d…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-01 20:49:49 RT @ezralevant: I declare war on the British Sandwich Association! https://t.co/X2yjx5wa1p cc. @BritSandwich #FreeTommy
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['british', '!'], 0.0, 0.0, None)])
# 2020-02-01 17:52:10 RT @ezralevant: I declare war on the British Sandwich Association! https://t.co/X2yjx5wa1p cc. @BritSandwich #FreeTommy
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['british', '!'], 0.0, 0.0, None)])
# 2020-02-01 17:20:16 RT @ezralevant: I declare war on the British Sandwich Association! https://t.co/X2yjx5wa1p cc. @BritSandwich #FreeTommy
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['british', '!'], 0.0, 0.0, None)])
# 2020-02-01 16:26:47 RT @ezralevant: I declare war on the British Sandwich Association! https://t.co/X2yjx5wa1p cc. @BritSandwich #FreeTommy
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['british', '!'], 0.0, 0.0, None)])
# 2020-02-01 16:23:13 RT @ezralevant: I declare war on the British Sandwich Association! https://t.co/X2yjx5wa1p cc. @BritSandwich #FreeTommy
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['british', '!'], 0.0, 0.0, None)])
# 2020-02-01 16:08:06 RT @ezralevant: I declare war on the British Sandwich Association! https://t.co/X2yjx5wa1p cc. @BritSandwich #FreeTommy
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['british', '!'], 0.0, 0.0, None)])
# 2020-02-01 16:00:32 RT @ezralevant: I declare war on the British Sandwich Association! https://t.co/X2yjx5wa1p cc. @BritSandwich #FreeTommy
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['british', '!'], 0.0, 0.0, None)])
# 2020-02-01 15:57:56 RT @ezralevant: I declare war on the British Sandwich Association! https://t.co/X2yjx5wa1p cc. @BritSandwich #FreeTommy
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['british', '!'], 0.0, 0.0, None)])
# 2020-02-01 09:41:56 #FreeTommy: Why Israeli fanboys back a U.K. far right anti-Muslim campaigner https://t.co/gk1KuX0nYm
# Sentiment(polarity=0.12857142857142856, subjectivity=0.5119047619047619, assessments=[(['back'], 0.0, 0.0, None), (['far'], 0.1, 1.0, None), (['right'], 0.2857142857142857, 0.5357142857142857, None)])
# 2020-02-01 02:37:29 @T_Clark18 @BGathletics @ESPNU Does the hoops team still have you blocked? #freetommy
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
