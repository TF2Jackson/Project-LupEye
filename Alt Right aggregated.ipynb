# %%
CONSUMER_KEY = 'a19MLVL0NMt7ByLp74Ey0hFN7'
CONSUMER_KEY_SECRET = 'q2KiIFKpwoLqXIIOjNAZ4zEm8h9Vmvwp8X3drcr0WeiLepdJYt'
ACCESS_TOKEN = '1167467648181035008-8PqoqisYZTNwAHxvmd6QqYmH2ztS6a'
ACCESS_TOKEN_SECRET = 'FnXJhL4a50kSTb5Bzr1Ix6cIfnXG6XxvrAPtPU7gmiyal'

import csv
import datetime
from datetime import date
import tweepy
from textblob import TextBlob

auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_KEY_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)

today = date.today()

csvFile = open(f'#Alt_Right_{today}.csv', 'a')
csvWriter = csv.writer(csvFile)

hashtags = ['#14Words','#Boogaloo','#ISaluteWhitePeople','#WhiteGenocide','#TCOT','#QAnon']
  
for i in hashtags:
    for tweet in tweepy.Cursor(api.search, q=i, count=100000, \
                                                   lang="en", \
                                                   ).items():

        tweet_dtg = str(tweet.created_at)
        todays = str(today)
        
        if todays in tweet_dtg:
            print(tweet.created_at, tweet.text, tweet.user.location)
            
            analysis = TextBlob(tweet.text)
            print(analysis.sentiment_assessments)

            csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8'), tweet.user.location, analysis.polarity, analysis.subjectivity])
# Out:
# 2020-02-24 13:28:30 @JeremyVineOn5 @jasminedotiwala @andrejpwalker @theJeremyVine ...then assume all white journis are brainwashing Bri… https://t.co/saIeV8Q6TC Penkridge, Staffordshire, UK
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['white'], 0.0, 0.0, None)])
# 2020-02-24 09:24:25 RT @StonehillBirch: #WhitePeople are the product of tens of thousands of years of evolution. For your descendant’s sake, don’t destroy your…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['destroy'], -0.2, 0.0, None)])
# 2020-02-24 23:40:31 RT @DaPholosopher: When you want that POP POP PURR!
#
# #shallnotbeinfringed #boogaloo #gunrights #kawaii #libertarian https://t.co/QszArFfYXl Washington, USA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 23:22:55 RT @DaPholosopher: When you want that POP POP PURR!
#
# #shallnotbeinfringed #boogaloo #gunrights #kawaii #libertarian https://t.co/QszArFfYXl Virginia, USA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 23:09:18 RT @DaPholosopher: When you want that POP POP PURR!
#
# #shallnotbeinfringed #boogaloo #gunrights #kawaii #libertarian https://t.co/QszArFfYXl Durango, CO
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 23:05:07 RT @Americasian1: If @BernieSanders somehow gets elected his platform will be against trillionaires.
# ___
#
# #Trump2020Landslide #MEMES #memes… Corruption, USA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 23:03:01 When you want that POP POP PURR!
#
# #shallnotbeinfringed #boogaloo #gunrights #kawaii #libertarian https://t.co/QszArFfYXl
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 22:59:36 Last Side quest. Godspeed warriors. #boogaloo #sidequest #NancyPelosi https://t.co/QmN32BLIri
# Sentiment(polarity=0.0, subjectivity=0.06666666666666667, assessments=[(['last'], 0.0, 0.06666666666666667, None)])
# 2020-02-24 22:42:41 @morganisawizard I need to step up my food prepping and stop stock piling ammo and equipment
# #Boogaloo Georgetown, TX
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 22:25:39 RT @Americasian1: If @BernieSanders somehow gets elected his platform will be against trillionaires.
# ___
#
# #Trump2020Landslide #MEMES #memes… Right behind ya boss
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 21:26:15 RT @Americasian1: If @BernieSanders somehow gets elected his platform will be against trillionaires.
# ___
#
# #Trump2020Landslide #MEMES #memes… Louisiana, USA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 21:20:17 @reason Imagine the memes though. This is going to be hilarious. I’m just let down that we don’t get Biden V Trump.… https://t.co/brOylAgmiU Kansas, USA
# Sentiment(polarity=0.17222222222222222, subjectivity=0.6444444444444445, assessments=[(['hilarious'], 0.5, 1.0, None), (['down'], -0.15555555555555559, 0.2888888888888889, None)])
# 2020-02-24 20:16:40 My calendar is open for Spring / Summer! Let's get together!
# Bookings: https://t.co/FCrcwvthz4
#
# #djlife #funk… https://t.co/ilbdOygWRo NYC
# Sentiment(polarity=0.0, subjectivity=0.5, assessments=[(['open', '!', '!'], 0.0, 0.5, None)])
# 2020-02-24 20:01:20 RT @Americasian1: If @BernieSanders somehow gets elected his platform will be against trillionaires.
# ___
#
# #Trump2020Landslide #MEMES #memes… Pennsylvania, USA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 19:59:12 RT @Americasian1: If @BernieSanders somehow gets elected his platform will be against trillionaires.
# ___
#
# #Trump2020Landslide #MEMES #memes… Hawaii, USA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 19:48:57 RT @Americasian1: Keep pushing left and reap what you sow.
# ___
# #Trump2020Landslide #MEMES #memesdaily #conservatives #trump2020 #kag2020 #k… Spanish Springs, NV
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['left'], 0.0, 0.0, None)])
# 2020-02-24 19:46:13 Thanks CryptoGumbo for the follow! Please welcome them to the pack! Come for the cancer jokes and wolf photos and stay for the #Boogaloo! Colorado, USA
# Sentiment(polarity=0.625, subjectivity=0.55, assessments=[(['thanks', '!'], 0.25, 0.2, None), (['welcome', '!', '!'], 1.0, 0.9, None)])
# 2020-02-24 19:42:01 RT @Americasian1: If @BernieSanders somehow gets elected his platform will be against trillionaires.
# ___
#
# #Trump2020Landslide #MEMES #memes… Zurich
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 19:39:45 RT @Americasian1: Keep pushing left and reap what you sow.
# ___
# #Trump2020Landslide #MEMES #memesdaily #conservatives #trump2020 #kag2020 #k… Zurich
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['left'], 0.0, 0.0, None)])
# 2020-02-24 19:12:13 RT @Americasian1: Keep pushing left and reap what you sow.
# ___
# #Trump2020Landslide #MEMES #memesdaily #conservatives #trump2020 #kag2020 #k… Phoenix, AZ
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['left'], 0.0, 0.0, None)])
# 2020-02-24 19:11:24 RT @Americasian1: Keep pushing left and reap what you sow.
# ___
# #Trump2020Landslide #MEMES #memesdaily #conservatives #trump2020 #kag2020 #k… Illinois, USA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['left'], 0.0, 0.0, None)])
# 2020-02-24 18:32:30 RT @TatianaG77: @boogaloo_radio @TGFoundation @beansonboogaloo @ZatannaTypes very thankful for the opportunity to speak about Congo 🇨🇩 #con… London, UK
# Sentiment(polarity=0.2, subjectivity=0.3, assessments=[(['very'], 0.2, 0.3, None)])
# 2020-02-24 18:05:43 RT @Americasian1: If @BernieSanders somehow gets elected his platform will be against trillionaires.
# ___
#
# #Trump2020Landslide #MEMES #memes… Texas, USA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 18:05:37 RT @Americasian1: If @BernieSanders somehow gets elected his platform will be against trillionaires.
# ___
#
# #Trump2020Landslide #MEMES #memes… Texas 🏖 Montana 🏞
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 17:51:19 RT @Americasian1: If @BernieSanders somehow gets elected his platform will be against trillionaires.
# ___
#
# #Trump2020Landslide #MEMES #memes… Nowhere
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 17:36:09 RT @Americasian1: If @BernieSanders somehow gets elected his platform will be against trillionaires.
# ___
#
# #Trump2020Landslide #MEMES #memes… Michigan, USA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 17:30:37 RT @Americasian1: If @BernieSanders somehow gets elected his platform will be against trillionaires.
# ___
#
# #Trump2020Landslide #MEMES #memes… NC piedmont
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 17:30:20 RT @Americasian1: If @BernieSanders somehow gets elected his platform will be against trillionaires.
# ___
#
# #Trump2020Landslide #MEMES #memes… Indiana, USA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 17:05:21 RT @Americasian1: If @BernieSanders somehow gets elected his platform will be against trillionaires.
# ___
#
# #Trump2020Landslide #MEMES #memes…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 17:03:52 RT @Americasian1: Keep pushing left and reap what you sow.
# ___
# #Trump2020Landslide #MEMES #memesdaily #conservatives #trump2020 #kag2020 #k…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['left'], 0.0, 0.0, None)])
# 2020-02-24 16:57:23 RT @Americasian1: If @BernieSanders somehow gets elected his platform will be against trillionaires.
# ___
#
# #Trump2020Landslide #MEMES #memes… Celeste, Texas
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 16:53:49 RT @Americasian1: Keep pushing left and reap what you sow.
# ___
# #Trump2020Landslide #MEMES #memesdaily #conservatives #trump2020 #kag2020 #k…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['left'], 0.0, 0.0, None)])
# 2020-02-24 16:52:13 RT @Americasian1: If @BernieSanders somehow gets elected his platform will be against trillionaires.
# ___
#
# #Trump2020Landslide #MEMES #memes… United States
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 16:52:00 RT @Americasian1: Keep pushing left and reap what you sow.
# ___
# #Trump2020Landslide #MEMES #memesdaily #conservatives #trump2020 #kag2020 #k… Texas, USA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['left'], 0.0, 0.0, None)])
# 2020-02-24 16:50:59 RT @Americasian1: Keep pushing left and reap what you sow.
# ___
# #Trump2020Landslide #MEMES #memesdaily #conservatives #trump2020 #kag2020 #k…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['left'], 0.0, 0.0, None)])
# 2020-02-24 16:43:48 RT @Americasian1: If @BernieSanders somehow gets elected his platform will be against trillionaires.
# ___
#
# #Trump2020Landslide #MEMES #memes…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 16:39:47 RT @Americasian1: If @BernieSanders somehow gets elected his platform will be against trillionaires.
# ___
#
# #Trump2020Landslide #MEMES #memes…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 16:39:25 RT @Americasian1: If @BernieSanders somehow gets elected his platform will be against trillionaires.
# ___
#
# #Trump2020Landslide #MEMES #memes…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 16:37:07 RT @Americasian1: If @BernieSanders somehow gets elected his platform will be against trillionaires.
# ___
#
# #Trump2020Landslide #MEMES #memes… Illinois, USA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 16:35:13 RT @Americasian1: If @BernieSanders somehow gets elected his platform will be against trillionaires.
# ___
#
# #Trump2020Landslide #MEMES #memes…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 16:34:07 RT @Americasian1: If @BernieSanders somehow gets elected his platform will be against trillionaires.
# ___
#
# #Trump2020Landslide #MEMES #memes… Buckingham, PA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 16:32:33 RT @Americasian1: If @BernieSanders somehow gets elected his platform will be against trillionaires.
# ___
#
# #Trump2020Landslide #MEMES #memes… westchester county, new york
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 16:29:53 RT @Americasian1: If @BernieSanders somehow gets elected his platform will be against trillionaires.
# ___
#
# #Trump2020Landslide #MEMES #memes…  Pittsburgh PA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 16:11:16 RT @Americasian1: If @BernieSanders somehow gets elected his platform will be against trillionaires.
# ___
#
# #Trump2020Landslide #MEMES #memes… Amarillo, TX
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 16:06:46 RT @thefreerifleman: In case you are looking for something to listen to today, @q_abolitionist @CryptoGumbo and I did a podcast at @unshack…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 15:59:44 RT @CtrlPew: The blessings of the Yeet-Angel are upon you. May your actions be well lubricated and your magazines full. So say we all. #ctr… Philadelphia, Pa
# Sentiment(polarity=0.35, subjectivity=0.55, assessments=[(['full'], 0.35, 0.55, None)])
# 2020-02-24 15:57:33 RT @Americasian1: If @BernieSanders somehow gets elected his platform will be against trillionaires.
# ___
#
# #Trump2020Landslide #MEMES #memes…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 15:56:34 If @BernieSanders somehow gets elected his platform will be against trillionaires.
# ___
#
# #Trump2020Landslide #MEMES… https://t.co/g8FLCVhFCw Deploragakure, MAGA Country
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 15:51:58 @boogaloo_radio @TGFoundation @beansonboogaloo @ZatannaTypes very thankful for the opportunity to speak about Congo… https://t.co/NLsDA33hBP London
# Sentiment(polarity=0.2, subjectivity=0.3, assessments=[(['very'], 0.2, 0.3, None)])
# 2020-02-24 15:51:34 RT @Americasian1: Thanks @Starbucks 🙊
# ___
# Trump2020Landslide #MEMES #memesdaily #voting #conservatives #trump2020 #kag2020 #kag #election20… Louisiana, USA
# Sentiment(polarity=0.2, subjectivity=0.2, assessments=[(['thanks'], 0.2, 0.2, None)])
# 2020-02-24 15:51:04 RT @Americasian1: Putin:
#
# Feeling cute...taking care of my plant.
# ___
# #Trump2020Landslide #MEMES #memesdaily #voting #conservatives #trump2… Louisiana, USA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 15:50:44 RT @Americasian1: Keep pushing left and reap what you sow.
# ___
# #Trump2020Landslide #MEMES #memesdaily #conservatives #trump2020 #kag2020 #k… Louisiana, USA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['left'], 0.0, 0.0, None)])
# 2020-02-24 15:08:29 RT @thefreerifleman: In case you are looking for something to listen to today, @q_abolitionist @CryptoGumbo and I did a podcast at @unshack…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 15:07:42 RT @sufisamwise: There is a national right-wing movement now planning an armed, violent Civil War called the 'Boogaloo' including overthrow… ÜT: 40.705285,-73.593013
# Sentiment(polarity=-0.8, subjectivity=1.0, assessments=[(['violent'], -0.8, 1.0, None)])
# 2020-02-24 15:05:10 In case you are looking for something to listen to today, @q_abolitionist @CryptoGumbo and I did a podcast at… https://t.co/Ltkwrx3HHH Collapsistan
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 13:21:12 RT @CtrlPew: The blessings of the Yeet-Angel are upon you. May your actions be well lubricated and your magazines full. So say we all. #ctr…
# Sentiment(polarity=0.35, subjectivity=0.55, assessments=[(['full'], 0.35, 0.55, None)])
# 2020-02-24 12:27:58 RT @Americasian1: Thanks @Starbucks 🙊
# ___
# Trump2020Landslide #MEMES #memesdaily #voting #conservatives #trump2020 #kag2020 #kag #election20… westchester county, new york
# Sentiment(polarity=0.2, subjectivity=0.2, assessments=[(['thanks'], 0.2, 0.2, None)])
# 2020-02-24 12:27:35 RT @Americasian1: Putin:
#
# Feeling cute...taking care of my plant.
# ___
# #Trump2020Landslide #MEMES #memesdaily #voting #conservatives #trump2… westchester county, new york
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 12:27:21 RT @Americasian1: Keep pushing left and reap what you sow.
# ___
# #Trump2020Landslide #MEMES #memesdaily #conservatives #trump2020 #kag2020 #k… westchester county, new york
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['left'], 0.0, 0.0, None)])
# 2020-02-24 12:26:11 RT @CtrlPew: The blessings of the Yeet-Angel are upon you. May your actions be well lubricated and your magazines full. So say we all. #ctr…
# Sentiment(polarity=0.35, subjectivity=0.55, assessments=[(['full'], 0.35, 0.55, None)])
# 2020-02-24 11:54:44 RT @Americasian1: Thanks @Starbucks 🙊
# ___
# Trump2020Landslide #MEMES #memesdaily #voting #conservatives #trump2020 #kag2020 #kag #election20…
# Sentiment(polarity=0.2, subjectivity=0.2, assessments=[(['thanks'], 0.2, 0.2, None)])
# 2020-02-24 11:28:43 RT @Americasian1: Thanks @Starbucks 🙊
# ___
# Trump2020Landslide #MEMES #memesdaily #voting #conservatives #trump2020 #kag2020 #kag #election20… Celeste, Texas
# Sentiment(polarity=0.2, subjectivity=0.2, assessments=[(['thanks'], 0.2, 0.2, None)])
# 2020-02-24 11:28:16 RT @Americasian1: Putin:
#
# Feeling cute...taking care of my plant.
# ___
# #Trump2020Landslide #MEMES #memesdaily #voting #conservatives #trump2… Celeste, Texas
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 11:28:00 RT @Americasian1: Keep pushing left and reap what you sow.
# ___
# #Trump2020Landslide #MEMES #memesdaily #conservatives #trump2020 #kag2020 #k… Celeste, Texas
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['left'], 0.0, 0.0, None)])
# 2020-02-24 08:40:00 @Judson4Congress If you think you're ready, please file a bill to this effect and kick it off.
#
# #boogaloo #SicSemperTyrannis Japan
# Sentiment(polarity=0.2, subjectivity=0.5, assessments=[(['ready'], 0.2, 0.5, None)])
# 2020-02-24 06:28:44 RT @Americasian1: Thanks @Starbucks 🙊
# ___
# Trump2020Landslide #MEMES #memesdaily #voting #conservatives #trump2020 #kag2020 #kag #election20…
# Sentiment(polarity=0.2, subjectivity=0.2, assessments=[(['thanks'], 0.2, 0.2, None)])
# 2020-02-24 06:26:51 RT @Americasian1: Keep pushing left and reap what you sow.
# ___
# #Trump2020Landslide #MEMES #memesdaily #conservatives #trump2020 #kag2020 #k… United States
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['left'], 0.0, 0.0, None)])
# 2020-02-24 06:26:39 RT @Americasian1: Putin:
#
# Feeling cute...taking care of my plant.
# ___
# #Trump2020Landslide #MEMES #memesdaily #voting #conservatives #trump2… United States
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 06:26:21 RT @Americasian1: Thanks @Starbucks 🙊
# ___
# Trump2020Landslide #MEMES #memesdaily #voting #conservatives #trump2020 #kag2020 #kag #election20… United States
# Sentiment(polarity=0.2, subjectivity=0.2, assessments=[(['thanks'], 0.2, 0.2, None)])
# 2020-02-24 03:13:39 RT if you're not voting in November
# #boogaloo2020 #boogaloo #elections
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:46:54 RT @Americasian1: Thanks @Starbucks 🙊
# ___
# Trump2020Landslide #MEMES #memesdaily #voting #conservatives #trump2020 #kag2020 #kag #election20… Corruption, USA
# Sentiment(polarity=0.2, subjectivity=0.2, assessments=[(['thanks'], 0.2, 0.2, None)])
# 2020-02-24 02:37:50 RT @Americasian1: Putin:
#
# Feeling cute...taking care of my plant.
# ___
# #Trump2020Landslide #MEMES #memesdaily #voting #conservatives #trump2… Corruption, USA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:37:19 RT @Americasian1: Keep pushing left and reap what you sow.
# ___
# #Trump2020Landslide #MEMES #memesdaily #conservatives #trump2020 #kag2020 #k… Corruption, USA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['left'], 0.0, 0.0, None)])
# 2020-02-24 02:26:33 RT @Americasian1: Keep pushing left and reap what you sow.
# ___
# #Trump2020Landslide #MEMES #memesdaily #conservatives #trump2020 #kag2020 #k…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['left'], 0.0, 0.0, None)])
# 2020-02-24 02:21:07 RT @Americasian1: Keep pushing left and reap what you sow.
# ___
# #Trump2020Landslide #MEMES #memesdaily #conservatives #trump2020 #kag2020 #k… Illinois, USA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['left'], 0.0, 0.0, None)])
# 2020-02-24 02:20:32 RT @Americasian1: Putin:
#
# Feeling cute...taking care of my plant.
# ___
# #Trump2020Landslide #MEMES #memesdaily #voting #conservatives #trump2… Illinois, USA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:17:45 RT @Americasian1: Thanks @Starbucks 🙊
# ___
# Trump2020Landslide #MEMES #memesdaily #voting #conservatives #trump2020 #kag2020 #kag #election20… Illinois, USA
# Sentiment(polarity=0.2, subjectivity=0.2, assessments=[(['thanks'], 0.2, 0.2, None)])
# 2020-02-24 01:03:09 RT @Americasian1: Putin:
#
# Feeling cute...taking care of my plant.
# ___
# #Trump2020Landslide #MEMES #memesdaily #voting #conservatives #trump2…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 01:01:01 RT @Americasian1: Putin:
#
# Feeling cute...taking care of my plant.
# ___
# #Trump2020Landslide #MEMES #memesdaily #voting #conservatives #trump2… Phoenix, Arizona 85006
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 01:00:50 RT @Americasian1: Putin:
#
# Feeling cute...taking care of my plant.
# ___
# #Trump2020Landslide #MEMES #memesdaily #voting #conservatives #trump2… Indianapolis
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 00:53:42 RT @Americasian1: Keep pushing left and reap what you sow.
# ___
# #Trump2020Landslide #MEMES #memesdaily #conservatives #trump2020 #kag2020 #k… Amarillo, TX
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['left'], 0.0, 0.0, None)])
# 2020-02-24 00:53:25 RT @Americasian1: Putin:
#
# Feeling cute...taking care of my plant.
# ___
# #Trump2020Landslide #MEMES #memesdaily #voting #conservatives #trump2… Amarillo, TX
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 00:52:12 RT @Americasian1: Thanks @Starbucks 🙊
# ___
# Trump2020Landslide #MEMES #memesdaily #voting #conservatives #trump2020 #kag2020 #kag #election20… Amarillo, TX
# Sentiment(polarity=0.2, subjectivity=0.2, assessments=[(['thanks'], 0.2, 0.2, None)])
# 2020-02-24 00:45:53 RT @DaPholosopher: I do a little simulator training and share a small sneak-peek.
#
# On YT: https://t.co/IsPBVz5byE
#
# #2a #gunrights #gunrange…
# Sentiment(polarity=-0.21875, subjectivity=0.45, assessments=[(['little'], -0.1875, 0.5, None), (['small'], -0.25, 0.4, None)])
# 2020-02-24 00:15:22 @rmgoldman1 @JTJohnson1982 @thehill So, no...its not safe to presume or root for one or another. Bring on the… https://t.co/Wp3caiKmLF El Monasterio De Mesa Verde
# Sentiment(polarity=-0.25, subjectivity=0.5, assessments=[(['not', 'safe'], -0.25, 0.5, None)])
# 2020-02-24 00:10:17 RT @Americasian1: Putin:
#
# Feeling cute...taking care of my plant.
# ___
# #Trump2020Landslide #MEMES #memesdaily #voting #conservatives #trump2… Virginia, USA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 00:09:27 RT @Americasian1: Thanks @Starbucks 🙊
# ___
# Trump2020Landslide #MEMES #memesdaily #voting #conservatives #trump2020 #kag2020 #kag #election20… Virginia, USA
# Sentiment(polarity=0.2, subjectivity=0.2, assessments=[(['thanks'], 0.2, 0.2, None)])
# 2020-02-24 23:47:18 @BBCWorld No forced "diversity"=no race war.
#
# #WhiteGenocide
# Sentiment(polarity=0.15000000000000002, subjectivity=0.2, assessments=[(['no', 'forced'], 0.15000000000000002, 0.2, None)])
# 2020-02-24 23:44:15 What's wrong with being white? #WhiteGenocide #itsokaytobewhite https://t.co/nW1W8MO3sk USA
# Sentiment(polarity=-0.25, subjectivity=0.45, assessments=[(['wrong'], -0.5, 0.9, None), (['white'], 0.0, 0.0, None)])
# 2020-02-24 21:57:48 RT @t_danecki: Only white people would ever be called nazi for not embracing their own genocide.
#
# "Anti-nazi" is a code word for anti-white… Clown World
# Sentiment(polarity=0.19999999999999998, subjectivity=0.6666666666666666, assessments=[(['only'], 0.0, 1.0, None), (['white'], 0.0, 0.0, None), (['own'], 0.6, 1.0, None)])
# 2020-02-24 21:53:27 Only white people would ever be called nazi for not embracing their own genocide.
#
# "Anti-nazi" is a code word for a… https://t.co/lfPOLTtfs3
# Sentiment(polarity=0.19999999999999998, subjectivity=0.6666666666666666, assessments=[(['only'], 0.0, 1.0, None), (['white'], 0.0, 0.0, None), (['own'], 0.6, 1.0, None)])
# 2020-02-24 20:47:14 ‘White Lives Don’t Matter’ Signs Appear In Canadian City, Media Ignores
#
# Read: https://t.co/JznvpF8foL
#
# #News… https://t.co/5GDVQSLnyU
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['white'], 0.0, 0.0, None)])
# 2020-02-24 20:43:22 RT @MikeGuillory9: @Frosted_Moo Yep. AntiWhites always
# 1. Label us with dehumanizing slurs for talking about #WhiteGenocide.
# 2. Deny #White…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 19:32:01 They are trying to convince you that you don't exist.
# - that your White ethnicity does not exist -
# This is "causing… https://t.co/6mxRo8RqA4
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['white'], 0.0, 0.0, None)])
# 2020-02-24 19:28:45 @USTechWorkers @SenMikeLee #MikeLee thinks you're #RACIST if you don't want to turn brown.
# Mike Lee wants… https://t.co/JRaSjsiXwG
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 18:07:09 RT @RealBtwixt: My latest video is here on BitChute. Be sure to SUBSCRIBE. #phillipscofield #CarolineFlack  #jamaicadeportations #whitegeno…
# Sentiment(polarity=0.5, subjectivity=0.8944444444444444, assessments=[(['latest'], 0.5, 0.9, None), (['sure'], 0.5, 0.8888888888888888, None)])
# 2020-02-24 17:30:29 RT @MikeGuillory9: @AMischling @lauraFWG @AW_HateWatch @wordofarebel @dirkmoses The US is an ethnostate. #AMERICAN is an ethnicity. But, th…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['american'], 0.0, 0.0, None)])
# 2020-02-24 17:28:06 @AMischling @lauraFWG @AW_HateWatch @wordofarebel @dirkmoses The US is an ethnostate. #AMERICAN is an ethnicity. Bu… https://t.co/FyGBovcg1T
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['american'], 0.0, 0.0, None)])
# 2020-02-24 17:09:43 @Frosted_Moo Yep. AntiWhites always
# 1. Label us with dehumanizing slurs for talking about #WhiteGenocide.
# 2. Deny… https://t.co/pqJPWTufRX
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 16:58:43 #AntiWhites deny #WhiteGenocide, then tell us why Whites deserve what we get, in the same sentence. https://t.co/3Trs9qPjtR
# Sentiment(polarity=0.0, subjectivity=0.125, assessments=[(['same'], 0.0, 0.125, None)])
# 2020-02-24 16:44:51 Are you starting to get it yet? They're trying to paint all whites, especially those who want to keep their #2A rig… https://t.co/Rp3yJVvcnA North Carolina, USA
# Sentiment(polarity=0.0, subjectivity=0.55, assessments=[(['starting'], 0.0, 0.1, None), (['especially'], 0.0, 1.0, None)])
# 2020-02-24 16:41:20 ❹ Now, #WhiteGenocide as 'Race War' is in full swing. Many Japanese folk don't yet know White Genocide. However, th… https://t.co/Qj7l7fXaNr Afterglow of the Ancient Japan
# Sentiment(polarity=0.2125, subjectivity=0.2625, assessments=[(['full'], 0.35, 0.55, None), (['many'], 0.5, 0.5, None), (['japanese'], 0.0, 0.0, None), (['white'], 0.0, 0.0, None)])
# 2020-02-24 16:37:22 #Maccabees #ThanksJews #NoHateAppState #AppState #UNC #ItsOkayToBeWhite
#
# We #Watauga #NC LOCAL #taxpayers wonder if… https://t.co/13lC5gGVTC North Carolina, USA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['local'], 0.0, 0.0, None)])
# 2020-02-24 16:23:52 RT @RightStuff47: "The Great Replacement" is Politically Correct code for #WhiteGenocide.
# Sentiment(polarity=0.4, subjectivity=0.425, assessments=[(['great'], 0.8, 0.75, None), (['politically'], 0.0, 0.1, None)])
# 2020-02-24 16:12:06 RT @MikeGuillory9: @AMischling @lauraFWG @wordofarebel @AW_HateWatch @dirkmoses Yeh, well, nobody is forcing non-Black immigrants on ONLY B… High On A Hilltop with Merle Haggard
# Sentiment(polarity=0.0, subjectivity=1.0, assessments=[(['only'], 0.0, 1.0, None)])
# 2020-02-24 16:07:48 Donald Trump, #AntiWhite fake president loves "Diversity".
#
# "Diversity" means #ChasingDownWhites.
#
# "Diversity" is a… https://t.co/Pf0NbwMW2E
# Sentiment(polarity=-0.5, subjectivity=1.0, assessments=[(['fake'], -0.5, 1.0, None)])
# 2020-02-24 16:04:53 RT @MikeGuillory9: @AMischling @lauraFWG @wordofarebel @AW_HateWatch @dirkmoses Yeh, well, nobody is forcing non-Black immigrants on ONLY B…
# Sentiment(polarity=0.0, subjectivity=1.0, assessments=[(['only'], 0.0, 1.0, None)])
# 2020-02-24 15:53:31 @AMischling @lauraFWG @wordofarebel @AW_HateWatch @dirkmoses Yeh, well, nobody is forcing non-Black immigrants on O… https://t.co/Y42LtZZ0WW
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 15:45:23 If Trump really cared about the White majority, the same White majority that got him elected, he'd do something to… https://t.co/Gha5nWk2Vh
# Sentiment(polarity=0.05, subjectivity=0.08125, assessments=[(['really'], 0.2, 0.2, None), (['white'], 0.0, 0.0, None), (['same'], 0.0, 0.125, None), (['white'], 0.0, 0.0, None)])
# 2020-02-24 15:34:00 RT @WhiteGenocideOz: Anti-racist  is a CODEWORD for anti-WHITE
# #WhiteGenocide
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 15:28:00 #AntiWhites deny #WhiteGenocide, then treat Whites as pure evil. https://t.co/mtmDAc8W7A
# Sentiment(polarity=-0.39285714285714285, subjectivity=0.75, assessments=[(['pure'], 0.21428571428571427, 0.5, None), (['evil'], -1.0, 1.0, None)])
# 2020-02-24 15:20:23 RT @WhiteGenocideOz: Anti-racist  is a CODEWORD for anti-WHITE
# #WhiteGenocide
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 14:21:23 @DrEtiquette @Jamierodr14 So is @MSNBC #MSNBC #NBC #MSM  saying that #BlackPeople &amp; #POC  #Antifa and other… https://t.co/LzgBymwndi Indiana, USA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 12:52:31 Dear Wonderful People 38: It's okay to be wonderful
#
# Music: "Forever And Ever" by Slik
#
# #ItsOkayToBeWhite… https://t.co/Kw5mebBnfy Sydney, Australia
# Sentiment(polarity=0.8333333333333334, subjectivity=0.8333333333333334, assessments=[(['wonderful'], 1.0, 1.0, None), (['okay'], 0.5, 0.5, None), (['wonderful'], 1.0, 1.0, None)])
# 2020-02-24 12:40:45 Testing 9 #WhiteGenocide
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 12:34:33 @getongab @realDonaldTrump @DonaldJTrumpJr @EricTrump
#
# Why don’t you do something about this and the Christian gen… https://t.co/9TehSG8bJU
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['christian'], 0.0, 0.0, None)])
# 2020-02-24 12:10:27 Dear Wonderful People 38: It's okay to be wonderful
#
# Music: "Forever And Ever" by Slik
#
# #ItsOkayToBeWhite… https://t.co/CMrqKgFy0d Sydney, Australia
# Sentiment(polarity=0.8333333333333334, subjectivity=0.8333333333333334, assessments=[(['wonderful'], 1.0, 1.0, None), (['okay'], 0.5, 0.5, None), (['wonderful'], 1.0, 1.0, None)])
# 2020-02-24 10:56:28 I bet Trey Parker probably posts in #WhiteGenocide
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 10:54:20 RT @NickGriffinBU: REPOSTED! My best-known speech in the #EuropeanParliament. Included in many videos about #WhiteGenocide and the #Coudenh…
# Sentiment(polarity=0.5, subjectivity=0.5, assessments=[(['many'], 0.5, 0.5, None)])
# 2020-02-24 10:33:11 No one says Indians, Chinese, Arabs, Africans etc should fight the "privilege" of their own race in government and… https://t.co/BmIL8vXVaW
# Sentiment(polarity=0.3, subjectivity=0.5, assessments=[(['chinese'], 0.0, 0.0, None), (['own'], 0.6, 1.0, None)])
# 2020-02-24 09:23:27 @NHSuk
# Start collecting proper data,
#
# Distinguising only for Coloured is bigoted,
#
# Why not for Whites ?… https://t.co/xDTxDzV5rd Planet Earth,  West Country UK
# Sentiment(polarity=0.0, subjectivity=0.55, assessments=[(['proper'], 0.0, 0.1, None), (['only'], 0.0, 1.0, None)])
# 2020-02-24 09:11:31 RT @t_danecki: @TheEconomist "Diversity" means chasing down the last white person.
#
# "Diversity" is a code word for #WhiteGenocide. AL
# Sentiment(polarity=-0.051851851851851864, subjectivity=0.11851851851851852, assessments=[(['down'], -0.15555555555555559, 0.2888888888888889, None), (['last'], 0.0, 0.06666666666666667, None), (['white'], 0.0, 0.0, None)])
# 2020-02-24 08:50:16 RT @WhiteGenocideOz: Anti-racist  is a CODEWORD for anti-WHITE
# #WhiteGenocide https://t.co/LNDnEEqX9U Newburgh, IN
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 08:29:14 RT @t_danecki: @TheEconomist "Diversity" means chasing down the last white person.
#
# "Diversity" is a code word for #WhiteGenocide.
# Sentiment(polarity=-0.051851851851851864, subjectivity=0.11851851851851852, assessments=[(['down'], -0.15555555555555559, 0.2888888888888889, None), (['last'], 0.0, 0.06666666666666667, None), (['white'], 0.0, 0.0, None)])
# 2020-02-24 08:27:18 @TheEconomist "Diversity" means chasing down the last white person.
#
# "Diversity" is a code word for #WhiteGenocide.
# Sentiment(polarity=-0.051851851851851864, subjectivity=0.11851851851851852, assessments=[(['down'], -0.15555555555555559, 0.2888888888888889, None), (['last'], 0.0, 0.06666666666666667, None), (['white'], 0.0, 0.0, None)])
# 2020-02-24 08:22:50 @thetimes No forced "diversity"=no race war.
#
# #WhiteGenocide
# Sentiment(polarity=0.15000000000000002, subjectivity=0.2, assessments=[(['no', 'forced'], 0.15000000000000002, 0.2, None)])
# 2020-02-24 07:51:16 RT @t_danecki: If whites are so evil why does everyone want to live with them?
#
# #WhiteGenocide https://t.co/chXhAqfPRp https://t.co/B41tDQE…
# Sentiment(polarity=-0.4318181818181818, subjectivity=0.75, assessments=[(['evil'], -1.0, 1.0, None), (['live'], 0.13636363636363635, 0.5, None)])
# 2020-02-24 07:41:06 RT @scwhiterabbit: #Diversity means chasing down the last White person, because no area is allowed to remain White. #ChasingDownWhites #whi… AL
# Sentiment(polarity=-0.038888888888888896, subjectivity=0.08888888888888889, assessments=[(['down'], -0.15555555555555559, 0.2888888888888889, None), (['last'], 0.0, 0.06666666666666667, None), (['white'], 0.0, 0.0, None), (['white'], 0.0, 0.0, None)])
# 2020-02-24 07:40:46 RT @WhiteGenocideOz: Anti-racist  is a CODEWORD for anti-WHITE
# #WhiteGenocide https://t.co/LNDnEEqX9U AL
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 07:35:56 RT @RightStuff47: ANYTHING "too White" ALWAYS needs "Diversity".
#
# "Diversity" means #ChasingDownWhites.
#
# "Diversity" is a code word for #Wh… AL
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['white'], 0.0, 0.0, None)])
# 2020-02-24 07:33:16 RT @MikeGuillory9: AntiWhites don't want to talk about #WhiteGenocide, they only want to stop normal White folks from pointing it out.
# Ther… AL
# Sentiment(polarity=0.049999999999999996, subjectivity=0.5499999999999999, assessments=[(['only'], 0.0, 1.0, None), (['normal'], 0.15, 0.6499999999999999, None), (['white'], 0.0, 0.0, None)])
# 2020-02-24 07:06:20 RT @t_danecki: If whites are so evil why does everyone want to live with them?
#
# #WhiteGenocide https://t.co/B41tDQE09W
# Sentiment(polarity=-0.4318181818181818, subjectivity=0.75, assessments=[(['evil'], -1.0, 1.0, None), (['live'], 0.13636363636363635, 0.5, None)])
# 2020-02-24 06:48:45 @metpoliceuk @AvivaPride @MetLGBT * while Police does nothing to protect British children from grooming gangs 😏… https://t.co/aLhHTUkF8W
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['british'], 0.0, 0.0, None)])
# 2020-02-24 06:22:55 RT @RightStuff47: "The Great Replacement" is Politically Correct code for #WhiteGenocide.
# Sentiment(polarity=0.4, subjectivity=0.425, assessments=[(['great'], 0.8, 0.75, None), (['politically'], 0.0, 0.1, None)])
# 2020-02-24 06:22:07 RT @RightStuff47: "Nazi" is an #AntiWhite hate word meaning any White person who doesn't want their race abolished.
#
# #AntiWhites hide behin…
# Sentiment(polarity=-0.4, subjectivity=0.45, assessments=[(['hate'], -0.8, 0.9, None), (['white'], 0.0, 0.0, None)])
# 2020-02-24 06:21:04 RT @AW_HatePatrol: The early days of the #FreeSpeech movement at #UCBerkeley in 1964. Just ahead and to the right of the students in the ph…
# Sentiment(polarity=0.19285714285714284, subjectivity=0.4178571428571428, assessments=[(['early'], 0.1, 0.3, None), (['right'], 0.2857142857142857, 0.5357142857142857, None)])
# 2020-02-24 06:15:42 RT @RightStuff47: It's not "Replacement".
#
# It's #WhiteGenocide.
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 06:13:45 RT @dav_s_: "Total sperm count in North America, Europe, Australia and New Zealand dropped by up to 60% and the trend is continuing."
#
# How…
# Sentiment(polarity=0.06818181818181818, subjectivity=0.6022727272727273, assessments=[(['total'], 0.0, 0.75, None), (['new'], 0.13636363636363635, 0.45454545454545453, None)])
# 2020-02-24 05:44:16 RT @t_danecki: If whites are so evil why does everyone want to live with them?
#
# #WhiteGenocide https://t.co/B41tDQE09W Brisbane Qld Male1963 Italian
# Sentiment(polarity=-0.4318181818181818, subjectivity=0.75, assessments=[(['evil'], -1.0, 1.0, None), (['live'], 0.13636363636363635, 0.5, None)])
# 2020-02-24 04:39:42 RT @WhiteGenocideOz: Anti-racist  is a CODEWORD for anti-WHITE
# #WhiteGenocide
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 04:35:19 RT @WhiteGenocideOz: Anti-racist  is a CODEWORD for anti-WHITE
# #WhiteGenocide Eatonton, GA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 04:34:46 RT @t_danecki: If whites are so evil why does everyone want to live with them?
#
# #WhiteGenocide https://t.co/B41tDQE09W
# Sentiment(polarity=-0.4318181818181818, subjectivity=0.75, assessments=[(['evil'], -1.0, 1.0, None), (['live'], 0.13636363636363635, 0.5, None)])
# 2020-02-24 04:34:00 RT @WhiteGenocideOz: Anti-racist  is a CODEWORD for anti-WHITE
# #WhiteGenocide https://t.co/LNDnEEqX9U High On A Hilltop with Merle Haggard
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 04:20:37 RT @t_danecki: If whites are so evil why does everyone want to live with them?
#
# #WhiteGenocide https://t.co/B41tDQE09W
# Sentiment(polarity=-0.4318181818181818, subjectivity=0.75, assessments=[(['evil'], -1.0, 1.0, None), (['live'], 0.13636363636363635, 0.5, None)])
# 2020-02-24 03:05:28 Anti-racist  is a CODEWORD for anti-WHITE
# #WhiteGenocide https://t.co/LNDnEEqX9U
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 01:39:09 RT @AW_HateWatch: His "Let's talk about it" means let's HIM talk about it.
#
# @dirkmoses's #students at @Stockton_edu:
#
# Listen to yourselves…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 01:38:34 "Nazi" is an #AntiWhite hate word meaning any White person who doesn't want their race abolished.
#
# #AntiWhites hide… https://t.co/ctalpjBYeH
# Sentiment(polarity=-0.4, subjectivity=0.45, assessments=[(['hate'], -0.8, 0.9, None), (['white'], 0.0, 0.0, None)])
# 2020-02-24 01:35:03 RT @t_danecki: How can you be pro-humanity if you support genocide?
#
# #WhiteGenocide https://t.co/g2BNaYwUVH
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 01:34:20 RT @Correction2016: The final battle on earth is #Whitegenocide.  This is what they are using to justify it. https://t.co/vS5qnaidUJ
# Sentiment(polarity=0.0, subjectivity=1.0, assessments=[(['final'], 0.0, 1.0, None)])
# 2020-02-24 01:33:27 RT @MikeGuillory9: AntiWhites don't want to talk about #WhiteGenocide, they only want to stop normal White folks from pointing it out.
# Ther…
# Sentiment(polarity=0.049999999999999996, subjectivity=0.5499999999999999, assessments=[(['only'], 0.0, 1.0, None), (['normal'], 0.15, 0.6499999999999999, None), (['white'], 0.0, 0.0, None)])
# 2020-02-24 01:30:30 RT @t_danecki: If whites are so evil why does everyone want to live with them?
#
# #WhiteGenocide https://t.co/chXhAqfPRp https://t.co/B41tDQE…
# Sentiment(polarity=-0.4318181818181818, subjectivity=0.75, assessments=[(['evil'], -1.0, 1.0, None), (['live'], 0.13636363636363635, 0.5, None)])
# 2020-02-24 01:28:18 RT @t_danecki: If whites are so evil why does everyone want to live with them?
#
# #WhiteGenocide https://t.co/chXhAqfPRp https://t.co/B41tDQE… Walla Walla
# Sentiment(polarity=-0.4318181818181818, subjectivity=0.75, assessments=[(['evil'], -1.0, 1.0, None), (['live'], 0.13636363636363635, 0.5, None)])
# 2020-02-24 01:10:19 @PuckHead313 A man that said “I’m innocent” admitted to rape? Yeah sure buddy take you jealously of the Black Man t… https://t.co/Fdfos17bsF Location
# Sentiment(polarity=0.2777777777777778, subjectivity=0.674074074074074, assessments=[(['innocent'], 0.5, 0.7, None), (['sure'], 0.5, 0.8888888888888888, None), (['black'], -0.16666666666666666, 0.43333333333333335, None)])
# 2020-02-24 23:59:58 RT @Tombx7M: This guy gets it
# The ultimate walk away
# Take a look
#
# #foxandfriends #MorningJoe #Trump
# #KAG2020LandslideVictory #TrumpPence20…
# Sentiment(polarity=0.0, subjectivity=1.0, assessments=[(['ultimate'], 0.0, 1.0, None)])
# 2020-02-24 23:59:51 RT @Tombx7M: This guy gets it
# The ultimate walk away
# Take a look
#
# #foxandfriends #MorningJoe #Trump
# #KAG2020LandslideVictory #TrumpPence20… West Texas
# Sentiment(polarity=0.0, subjectivity=1.0, assessments=[(['ultimate'], 0.0, 1.0, None)])
# 2020-02-24 23:59:45 RT @Tombx7M: This guy gets it
# The ultimate walk away
# Take a look
#
# #foxandfriends #MorningJoe #Trump
# #KAG2020LandslideVictory #TrumpPence20… Sunny Southern California
# Sentiment(polarity=0.0, subjectivity=1.0, assessments=[(['ultimate'], 0.0, 1.0, None)])
# 2020-02-24 23:59:21 RT @TeriGRight: I like Doug Collins. But his decision to split the #GAGOP vote in a jungle primary, is dangerously flawed judgement.
#
# And i…
# Sentiment(polarity=-0.04999999999999999, subjectivity=0.5, assessments=[(['primary'], 0.4, 0.5, None), (['dangerously', 'flawed'], -0.5, 0.5, None)])
# 2020-02-24 23:59:07 RT @Tombx7M: This guy gets it
# The ultimate walk away
# Take a look
#
# #foxandfriends #MorningJoe #Trump
# #KAG2020LandslideVictory #TrumpPence20…
# Sentiment(polarity=0.0, subjectivity=1.0, assessments=[(['ultimate'], 0.0, 1.0, None)])
# 2020-02-24 23:59:04 RT @Tombx7M: This guy gets it
# The ultimate walk away
# Take a look
#
# #foxandfriends #MorningJoe #Trump
# #KAG2020LandslideVictory #TrumpPence20… USA
# Sentiment(polarity=0.0, subjectivity=1.0, assessments=[(['ultimate'], 0.0, 1.0, None)])
# 2020-02-24 23:58:49 RT @CatholicForLife: I thought letting baby's die was #ChildAbuse &amp; #Murder #prolife #tcot  https://t.co/O2jMtsbIb3
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 23:58:32 RT @Tombx7M: This guy gets it
# The ultimate walk away
# Take a look
#
# #foxandfriends #MorningJoe #Trump
# #KAG2020LandslideVictory #TrumpPence20… Bandera Tx,
# Sentiment(polarity=0.0, subjectivity=1.0, assessments=[(['ultimate'], 0.0, 1.0, None)])
# 2020-02-24 23:58:15 Saving Babies More Important than Winning Sports Titles, Tim Tebow Says https://t.co/TkZRMJHkBc #MAGA #tcot #pjnet The Anti-Anti-Trump Right
# Sentiment(polarity=0.4666666666666666, subjectivity=0.75, assessments=[(['more'], 0.5, 0.5, None), (['important'], 0.4, 1.0, None), (['winning'], 0.5, 0.75, None)])
# 2020-02-24 23:58:15 RT @Tombx7M: This guy gets it
# The ultimate walk away
# Take a look
#
# #foxandfriends #MorningJoe #Trump
# #KAG2020LandslideVictory #TrumpPence20… Bozeman, MT
# Sentiment(polarity=0.0, subjectivity=1.0, assessments=[(['ultimate'], 0.0, 1.0, None)])
# 2020-02-24 23:57:59 RT @Tombx7M: This guy gets it
# The ultimate walk away
# Take a look
#
# #foxandfriends #MorningJoe #Trump
# #KAG2020LandslideVictory #TrumpPence20…
# Sentiment(polarity=0.0, subjectivity=1.0, assessments=[(['ultimate'], 0.0, 1.0, None)])
# 2020-02-24 23:56:54 RT @Tombx7M: The coronavirus is doing what it was designed to do spread.
#
# #foxandfriends #MorningJoe #Trump
# #KAG2020LandslideVictory #Trum… NJ
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 23:56:44 RT @Tombx7M: This guy gets it
# The ultimate walk away
# Take a look
#
# #foxandfriends #MorningJoe #Trump
# #KAG2020LandslideVictory #TrumpPence20…
# Sentiment(polarity=0.0, subjectivity=1.0, assessments=[(['ultimate'], 0.0, 1.0, None)])
# 2020-02-24 23:56:39 Barred
# Easy
# Noontime
# Gamines
# Holograph
# Adamantly
# Zingers
# Infiltrator
#
# #benghazi #tcot Benghazi
# Sentiment(polarity=0.26666666666666666, subjectivity=0.7666666666666666, assessments=[(['easy'], 0.43333333333333335, 0.8333333333333334, None), (['adamantly'], 0.1, 0.7, None)])
# 2020-02-24 23:55:48 RT @RebelNewsOnline: .@MaximeBernier and @ezralevant talk about the rapid erosion of free speech rights in #Canada.
#
# WATCH: https://t.co/H5…
# Sentiment(polarity=0.4, subjectivity=0.8, assessments=[(['free'], 0.4, 0.8, None)])
# 2020-02-24 23:55:10 RT @Tombx7M: The coronavirus is doing what it was designed to do spread.
#
# #foxandfriends #MorningJoe #Trump
# #KAG2020LandslideVictory #Trum… Washington, USA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 23:55:10 RT @Tombx7M: The coronavirus is doing what it was designed to do spread.
#
# #foxandfriends #MorningJoe #Trump
# #KAG2020LandslideVictory #Trum…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 23:55:10 RT @TeriGRight: I like Doug Collins. But his decision to split the #GAGOP vote in a jungle primary, is dangerously flawed judgement.
#
# And i… Pennsylvania, USA
# Sentiment(polarity=-0.04999999999999999, subjectivity=0.5, assessments=[(['primary'], 0.4, 0.5, None), (['dangerously', 'flawed'], -0.5, 0.5, None)])
# 2020-02-24 23:54:49 RT @Tombx7M: The coronavirus is doing what it was designed to do spread.
#
# #foxandfriends #MorningJoe #Trump
# #KAG2020LandslideVictory #Trum… Florida, USA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 23:54:48 RT @MaryfromMarin: Hating Trump Can’t Unite the Democrats [Daniel Greenfield]
#  https://t.co/iiMTNKFSAR #RedNationRising #tcot #ccot #ycot @…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 23:54:33 RT @MARINE_99ZULU: Listening to the dumbasses in #Austin #Texas explain why they like #Bernie, is like sticking a knife if your ear...  Dum… Texas, USA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 23:54:24 RT @Tombx7M: The coronavirus is doing what it was designed to do spread.
#
# #foxandfriends #MorningJoe #Trump
# #KAG2020LandslideVictory #Trum… United States
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 23:54:19 RT @Tombx7M: This guy gets it
# The ultimate walk away
# Take a look
#
# #foxandfriends #MorningJoe #Trump
# #KAG2020LandslideVictory #TrumpPence20…
# Sentiment(polarity=0.0, subjectivity=1.0, assessments=[(['ultimate'], 0.0, 1.0, None)])
# 2020-02-24 23:54:12 RT @Tombx7M: This guy gets it
# The ultimate walk away
# Take a look
#
# #foxandfriends #MorningJoe #Trump
# #KAG2020LandslideVictory #TrumpPence20… Charlotte, NC
# Sentiment(polarity=0.0, subjectivity=1.0, assessments=[(['ultimate'], 0.0, 1.0, None)])
# 2020-02-24 23:53:05 RT @MaryfromMarin: Hating Trump Can’t Unite the Democrats [Daniel Greenfield]
#  https://t.co/iiMTNKFSAR #RedNationRising #tcot #ccot #ycot @… SF Bay Area
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 23:52:38 RT @TeriGRight: I like Doug Collins. But his decision to split the #GAGOP vote in a jungle primary, is dangerously flawed judgement.
#
# And i… Va. Beach,Va.
# Sentiment(polarity=-0.04999999999999999, subjectivity=0.5, assessments=[(['primary'], 0.4, 0.5, None), (['dangerously', 'flawed'], -0.5, 0.5, None)])
# 2020-02-24 23:52:22 RT @Tombx7M: This guy gets it
# The ultimate walk away
# Take a look
#
# #foxandfriends #MorningJoe #Trump
# #KAG2020LandslideVictory #TrumpPence20… United States
# Sentiment(polarity=0.0, subjectivity=1.0, assessments=[(['ultimate'], 0.0, 1.0, None)])
# 2020-02-24 23:52:14 I thought letting baby's die was #ChildAbuse &amp; #Murder #prolife #tcot  https://t.co/O2jMtsbIb3 San Diego, CA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 23:51:36 RT @BraveLad: #POLL What below best describes Bernie Sanders? #TCOT #MAGA #TRUMP2020 #CCOT #PROLIFE #2A #TEAPARTY #ZIONIST https://t.co/2FM… NC to TX
# Sentiment(polarity=1.0, subjectivity=0.3, assessments=[(['best'], 1.0, 0.3, None)])
# 2020-02-24 23:51:21 RT @GrahamLedger: Tonight: The #Marxist message. With each victory, #BernieSanders becomes more emboldened to attack the #constitution. Als… Branson West,MO USA
# Sentiment(polarity=0.5, subjectivity=0.5, assessments=[(['more'], 0.5, 0.5, None)])
# 2020-02-24 23:51:08 RT @GrahamLedger: Tonight: The #Marxist message. With each victory, #BernieSanders becomes more emboldened to attack the #constitution. Als…
# Sentiment(polarity=0.5, subjectivity=0.5, assessments=[(['more'], 0.5, 0.5, None)])
# 2020-02-24 23:51:04 RT @TeriGRight: I like Doug Collins. But his decision to split the #GAGOP vote in a jungle primary, is dangerously flawed judgement.
#
# And i… THE U S of By God A
# Sentiment(polarity=-0.04999999999999999, subjectivity=0.5, assessments=[(['primary'], 0.4, 0.5, None), (['dangerously', 'flawed'], -0.5, 0.5, None)])
# 2020-02-24 23:50:41 RT @MARINE_99ZULU: Listening to the dumbasses in #Austin #Texas explain why they like #Bernie, is like sticking a knife if your ear...  Dum… Florida, USA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 23:50:39 RT @MaryfromMarin: Hating Trump Can’t Unite the Democrats [Daniel Greenfield]
#  https://t.co/iiMTNKFSAR #RedNationRising #tcot #ccot #ycot @… Nevada, USA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 23:50:39 RT @Tombx7M: The coronavirus is doing what it was designed to do spread.
#
# #foxandfriends #MorningJoe #Trump
# #KAG2020LandslideVictory #Trum… United States
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 23:50:27 Virginia State Senator says dems voted against raises for cops as payback for defending 2nd Amendment #tcot https://t.co/aoWxYeY3ji MI - CA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['2nd'], 0.0, 0.0, None)])
# 2020-02-24 23:50:04 RT @TeriGRight: I like Doug Collins. But his decision to split the #GAGOP vote in a jungle primary, is dangerously flawed judgement.
#
# And i… Pennsylvania
# ...
# 2020-02-24 02:25:05 RT @Tombx7M: Don’t earn it
# Just take it
#
# #foxandfriends #MorningJoe #Trump
# #KAG2020LandslideVictory #TrumpPence2020 #Tcot
# #Ccot  #KAGA2020… USA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:24:56 RT @Tombx7M: Can’t make this stuff up..
#
# #foxandfriends #SundayMorning #CNNSOTU
# #KAG2020LandslideVictory #TrumpPence2020 #Tcot
# #Ccot #Satu…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:24:40 RT @JohnKStahlUSA: Bern is gaining traction. Lived in mommy’s basement before it was fashionable. Never had a real job. Honeymooned in Sovi… United States
# Sentiment(polarity=0.2, subjectivity=0.30000000000000004, assessments=[(['real'], 0.2, 0.30000000000000004, None)])
# 2020-02-24 02:24:21 RT @Tombx7M: Can’t make this stuff up..
#
# #foxandfriends #SundayMorning #CNNSOTU
# #KAG2020LandslideVictory #TrumpPence2020 #Tcot
# #Ccot #Satu…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:23:00 Obama DHS Whistleblower Found Dead with 'Gunshot Wound' to the Chest https://t.co/dp2ZUVGO9m #MAGA #tcot #pjnet The Anti-Anti-Trump Right
# Sentiment(polarity=-0.2, subjectivity=0.4, assessments=[(['dead'], -0.2, 0.4, None)])
# 2020-02-24 02:22:59 RT @Tombx7M: The freeloading Bernie bus is on a roll
#
# #foxandfriends #SundayMorning #CNNSOTU
# #KAG2020LandslideVictory #TrumpPence2020 #Tco…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:22:56 RT @Tombx7M: Don’t earn it
# Just take it
#
# #foxandfriends #MorningJoe #Trump
# #KAG2020LandslideVictory #TrumpPence2020 #Tcot
# #Ccot  #KAGA2020…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:22:54 RT @Tombx7M: Don’t earn it
# Just take it
#
# #foxandfriends #MorningJoe #Trump
# #KAG2020LandslideVictory #TrumpPence2020 #Tcot
# #Ccot  #KAGA2020… Texas, USA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:22:47 RT @Tombx7M: Don’t earn it
# Just take it
#
# #foxandfriends #MorningJoe #Trump
# #KAG2020LandslideVictory #TrumpPence2020 #Tcot
# #Ccot  #KAGA2020… 🇺🇸🇺🇸🇺🇸
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:22:36 RT @Tombx7M: The freeloading Bernie bus is on a roll
#
# #foxandfriends #SundayMorning #CNNSOTU
# #KAG2020LandslideVictory #TrumpPence2020 #Tco… #Trumpville
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:22:05 RT @TUSCNetwork: To get mass adoption, we thought a lot about which industry to target first. We chose the U.S. firearms industry because i…
# Sentiment(polarity=0.25, subjectivity=0.3333333333333333, assessments=[(['first'], 0.25, 0.3333333333333333, None)])
# 2020-02-24 02:21:39 RT @Tombx7M: Don’t earn it
# Just take it
#
# #foxandfriends #MorningJoe #Trump
# #KAG2020LandslideVictory #TrumpPence2020 #Tcot
# #Ccot  #KAGA2020… #Trumpville
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:21:27 RT @Tombx7M: Can’t make this stuff up..
#
# #foxandfriends #SundayMorning #CNNSOTU
# #KAG2020LandslideVictory #TrumpPence2020 #Tcot
# #Ccot #Satu… Louisiana, USA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:21:25 RT @Tombx7M: Can’t make this stuff up..
#
# #foxandfriends #SundayMorning #CNNSOTU
# #KAG2020LandslideVictory #TrumpPence2020 #Tcot
# #Ccot #Satu…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:21:24 RT @Tombx7M: Can’t make this stuff up..
#
# #foxandfriends #SundayMorning #CNNSOTU
# #KAG2020LandslideVictory #TrumpPence2020 #Tcot
# #Ccot #Satu… Valles Marineris
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:21:23 RT @Tombx7M: Can’t make this stuff up..
#
# #foxandfriends #SundayMorning #CNNSOTU
# #KAG2020LandslideVictory #TrumpPence2020 #Tcot
# #Ccot #Satu… #Trumpville
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:21:07 RT @Tombx7M: Don’t earn it
# Just take it
#
# #foxandfriends #MorningJoe #Trump
# #KAG2020LandslideVictory #TrumpPence2020 #Tcot
# #Ccot  #KAGA2020…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:21:04 RT @Tombx7M: Don’t earn it
# Just take it
#
# #foxandfriends #MorningJoe #Trump
# #KAG2020LandslideVictory #TrumpPence2020 #Tcot
# #Ccot  #KAGA2020… Pennsylvania, USA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:19:56 RT @Tombx7M: Don’t earn it
# Just take it
#
# #foxandfriends #MorningJoe #Trump
# #KAG2020LandslideVictory #TrumpPence2020 #Tcot
# #Ccot  #KAGA2020… Western Mountains, NC. USA.
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:19:34 RT @Tombx7M: The freeloading Bernie bus is on a roll
#
# #foxandfriends #SundayMorning #CNNSOTU
# #KAG2020LandslideVictory #TrumpPence2020 #Tco… Illinois, USA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:18:56 RT @Tombx7M: Can’t make this stuff up..
#
# #foxandfriends #SundayMorning #CNNSOTU
# #KAG2020LandslideVictory #TrumpPence2020 #Tcot
# #Ccot #Satu… Western Mountains, NC. USA.
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:18:51 RT @Tombx7M: Don’t earn it
# Just take it
#
# #foxandfriends #MorningJoe #Trump
# #KAG2020LandslideVictory #TrumpPence2020 #Tcot
# #Ccot  #KAGA2020… Colorado, USA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:18:07 RT @Tombx7M: Can’t make this stuff up..
#
# #foxandfriends #SundayMorning #CNNSOTU
# #KAG2020LandslideVictory #TrumpPence2020 #Tcot
# #Ccot #Satu…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:17:43 RT @Tombx7M: Don’t earn it
# Just take it
#
# #foxandfriends #MorningJoe #Trump
# #KAG2020LandslideVictory #TrumpPence2020 #Tcot
# #Ccot  #KAGA2020… USA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:17:38 RT @Tombx7M: Don’t earn it
# Just take it
#
# #foxandfriends #MorningJoe #Trump
# #KAG2020LandslideVictory #TrumpPence2020 #Tcot
# #Ccot  #KAGA2020… Rent Free in Libs Heads
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:17:15 RT @Tombx7M: Don’t earn it
# Just take it
#
# #foxandfriends #MorningJoe #Trump
# #KAG2020LandslideVictory #TrumpPence2020 #Tcot
# #Ccot  #KAGA2020… USA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:17:04 RT @Tombx7M: Can’t make this stuff up..
#
# #foxandfriends #SundayMorning #CNNSOTU
# #KAG2020LandslideVictory #TrumpPence2020 #Tcot
# #Ccot #Satu… Rent Free in Libs Heads
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:16:42 RT @Tombx7M: Can’t make this stuff up..
#
# #foxandfriends #SundayMorning #CNNSOTU
# #KAG2020LandslideVictory #TrumpPence2020 #Tcot
# #Ccot #Satu… North America
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:16:39 RT @SooperMexican: In light of the crazy properopinion debacle, what’s your favorite right-wing twitter personality kerfuffle? There are so… Maryland
# Sentiment(polarity=0.10000000000000002, subjectivity=0.8666666666666667, assessments=[(['light'], 0.4, 0.7, None), (['crazy'], -0.6, 0.9, None), (['favorite'], 0.5, 1.0, None)])
# 2020-02-24 02:16:35 RT @Tombx7M: The freeloading Bernie bus is on a roll
#
# #foxandfriends #SundayMorning #CNNSOTU
# #KAG2020LandslideVictory #TrumpPence2020 #Tco… Rent Free in Libs Heads
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:16:11 RT @Tombx7M: Don’t earn it
# Just take it
#
# #foxandfriends #MorningJoe #Trump
# #KAG2020LandslideVictory #TrumpPence2020 #Tcot
# #Ccot  #KAGA2020… Boston, MA aka Titetown
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:15:24 RT @Tombx7M: Don’t earn it
# Just take it
#
# #foxandfriends #MorningJoe #Trump
# #KAG2020LandslideVictory #TrumpPence2020 #Tcot
# #Ccot  #KAGA2020… Apex, NC
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:14:59 RT @Tombx7M: Don’t earn it
# Just take it
#
# #foxandfriends #MorningJoe #Trump
# #KAG2020LandslideVictory #TrumpPence2020 #Tcot
# #Ccot  #KAGA2020… USA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:14:53 #StateOfTheUnion Quote T-Shirt - "The Best is Yet to Come" https://t.co/Src6k6WG6x
# #Tcot #Tgdn #Ccot #Teaparty… https://t.co/WNY4QchLXp New Jersey, USA
# Sentiment(polarity=1.0, subjectivity=0.3, assessments=[(['best'], 1.0, 0.3, None)])
# 2020-02-24 02:14:24 RT @jaazee1: If you are concerned that the Caronavirus putting major Chinese cities on lockdown is man-made, you are called a conspiracy th… Australia
# Sentiment(polarity=0.03125, subjectivity=0.25, assessments=[(['major'], 0.0625, 0.5, None), (['chinese'], 0.0, 0.0, None)])
# 2020-02-24 02:13:19 RT @Tombx7M: Don’t earn it
# Just take it
#
# #foxandfriends #MorningJoe #Trump
# #KAG2020LandslideVictory #TrumpPence2020 #Tcot
# #Ccot  #KAGA2020… 🇺🇸America🇺🇸
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:13:18 RT @Tombx7M: Can’t make this stuff up..
#
# #foxandfriends #SundayMorning #CNNSOTU
# #KAG2020LandslideVictory #TrumpPence2020 #Tcot
# #Ccot #Satu… lost in time
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:13:01 DEMOCRACY DIES IN DARKNESS: Nevada Democrats Requiring Caucus Volunteers To Sign Non-Disclosure Agreements… https://t.co/Vb02CO5pqb The Anti-Anti-Trump Right
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:12:49 RT @Tombx7M: Bernie Sanders is like the coronavirus to the Democrats
#
# #foxandfriends #SundayMorning #CNNSOTU
# #KAG2020LandslideVictory #Tru…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:12:47 RT @Tombx7M: Don’t earn it
# Just take it
#
# #foxandfriends #MorningJoe #Trump
# #KAG2020LandslideVictory #TrumpPence2020 #Tcot
# #Ccot  #KAGA2020… Sebastian, FL
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:12:46 RT @Tombx7M: Don’t earn it
# Just take it
#
# #foxandfriends #MorningJoe #Trump
# #KAG2020LandslideVictory #TrumpPence2020 #Tcot
# #Ccot  #KAGA2020… In the messed up state of Ca.
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:12:02 RT @factandrumor: #Greta is amazing!  I'm very proud of her.  She's done more on this issue than #Trump and #Congress combined.  Keep up th… 41° 54' 8.02'' N 12° 27' 29" E
# Sentiment(polarity=0.75, subjectivity=0.7999999999999999, assessments=[(['amazing', '!'], 0.7500000000000001, 0.9, None), (['very', 'proud'], 1.0, 1.0, None), (['more'], 0.5, 0.5, None)])
# 2020-02-24 02:11:46 RT @Tombx7M: Don’t earn it
# Just take it
#
# #foxandfriends #MorningJoe #Trump
# #KAG2020LandslideVictory #TrumpPence2020 #Tcot
# #Ccot  #KAGA2020…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:11:25 Bill Clinton was the Real Threat to US National Security, Not President Trump: https://t.co/v4QSbceEha #tcot USA
# Sentiment(polarity=0.2, subjectivity=0.30000000000000004, assessments=[(['real'], 0.2, 0.30000000000000004, None)])
# 2020-02-24 02:11:18 RT @Tombx7M: Can’t make this stuff up..
#
# #foxandfriends #SundayMorning #CNNSOTU
# #KAG2020LandslideVictory #TrumpPence2020 #Tcot
# #Ccot #Satu… So California, USA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:11:17 RT @EconomicMayhem: #tcot "Top News" Story: @JohnKStahlUSA: 'Bern is gaining traction. Lived in mommy’s basement before it was fashionable.… Covington, KY
# Sentiment(polarity=0.5, subjectivity=0.5, assessments=[(['top'], 0.5, 0.5, None)])
# 2020-02-24 02:11:17 RT @Tombx7M: Don’t earn it
# Just take it
#
# #foxandfriends #MorningJoe #Trump
# #KAG2020LandslideVictory #TrumpPence2020 #Tcot
# #Ccot  #KAGA2020… Trump’s America🇺🇸
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:11:12 RT @Tombx7M: Can’t make this stuff up..
#
# #foxandfriends #SundayMorning #CNNSOTU
# #KAG2020LandslideVictory #TrumpPence2020 #Tcot
# #Ccot #Satu… In the messed up state of Ca.
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:11:09 RT @Tombx7M: The freeloading Bernie bus is on a roll
#
# #foxandfriends #SundayMorning #CNNSOTU
# #KAG2020LandslideVictory #TrumpPence2020 #Tco…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:10:59 RT @Tombx7M: The freeloading Bernie bus is on a roll
#
# #foxandfriends #SundayMorning #CNNSOTU
# #KAG2020LandslideVictory #TrumpPence2020 #Tco…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:10:59 RT @Tombx7M: The freeloading Bernie bus is on a roll
#
# #foxandfriends #SundayMorning #CNNSOTU
# #KAG2020LandslideVictory #TrumpPence2020 #Tco…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:10:18 RT @Tombx7M: The freeloading Bernie bus is on a roll
#
# #foxandfriends #SundayMorning #CNNSOTU
# #KAG2020LandslideVictory #TrumpPence2020 #Tco… In the messed up state of Ca.
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:09:42 RT @Tombx7M: The freeloading Bernie bus is on a roll
#
# #foxandfriends #SundayMorning #CNNSOTU
# #KAG2020LandslideVictory #TrumpPence2020 #Tco… America
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:09:27 #tcot "Top News" Story: @JohnKStahlUSA: 'Bern is gaining traction. Lived in mommy’s basement before it was fashiona… https://t.co/Q4vXZkYYR3 Asia
# Sentiment(polarity=0.5, subjectivity=0.5, assessments=[(['top'], 0.5, 0.5, None)])
# 2020-02-24 02:08:50 RT @Tombx7M: Don’t earn it
# Just take it
#
# #foxandfriends #MorningJoe #Trump
# #KAG2020LandslideVictory #TrumpPence2020 #Tcot
# #Ccot  #KAGA2020… United States
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:08:27 RT @Tombx7M: Can’t make this stuff up..
#
# #foxandfriends #SundayMorning #CNNSOTU
# #KAG2020LandslideVictory #TrumpPence2020 #Tcot
# #Ccot #Satu… Texas, USA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:08:25 RT @Tombx7M: Can’t make this stuff up..
#
# #foxandfriends #SundayMorning #CNNSOTU
# #KAG2020LandslideVictory #TrumpPence2020 #Tcot
# #Ccot #Satu…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-24 02:07:28 RT @Tombx7M: Can’t make this stuff up..
#
# #foxandfriends #SundayMorning #CNNSOTU
# #KAG2020LandslideVictory #TrumpPence2020 #Tcot
# #Ccot #Satu… Delaware, USA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-1-f09a3ada8c0e> in <module>
#      23 for i in hashtags:
#      24     for tweet in tweepy.Cursor(api.search, q=i, count=100000, \
# ---> 25                                                    lang="en", \
#      26                                                    ).items():
#      27
#
# /Applications/anaconda3/lib/python3.7/site-packages/tweepy/cursor.py in __next__(self)
#      45
#      46     def __next__(self):
# ---> 47         return self.next()
#      48
#      49     def next(self):
#
# /Applications/anaconda3/lib/python3.7/site-packages/tweepy/cursor.py in next(self)
#     193         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     194             # Reached end of current page, get the next page...
# --> 195             self.current_page = self.page_iterator.next()
#     196             self.page_index = -1
#     197         self.page_index += 1
#
# /Applications/anaconda3/lib/python3.7/site-packages/tweepy/cursor.py in next(self)
#     104
#     105         if self.index >= len(self.results) - 1:
# --> 106             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kargs)
#     107
#     108             if hasattr(self.method, '__self__'):
#
# /Applications/anaconda3/lib/python3.7/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     248                 return method
#     249             else:
# --> 250                 return method.execute()
#     251         finally:
#     252             method.session.close()
#
# /Applications/anaconda3/lib/python3.7/site-packages/tweepy/binder.py in execute(self)
#     231                     raise RateLimitError(error_msg, resp)
#     232                 else:
# --> 233                     raise TweepError(error_msg, resp, api_code=api_error_code)
#     234
#     235             # Parse the response payload
#
# TweepError: Twitter error response: status code = 429

# %%
todays = str(today)
print(todays)
type(todays)
# Out:
# 2020-02-24
# str
