# %%
# Input my keys and tokens from Twitter; allows use of Tweepy API

CONSUMER_KEY = 'a19MLVL0NMt7ByLp74Ey0hFN7'
CONSUMER_KEY_SECRET = 'q2KiIFKpwoLqXIIOjNAZ4zEm8h9Vmvwp8X3drcr0WeiLepdJYt'
ACCESS_TOKEN = '1167467648181035008-8PqoqisYZTNwAHxvmd6QqYmH2ztS6a'
ACCESS_TOKEN_SECRET = 'FnXJhL4a50kSTb5Bzr1Ix6cIfnXG6XxvrAPtPU7gmiyal'

# Import dependencies and libraries 

import csv
    # We write the scraped tweets into a .csv file to a) run it through LIWC easily and b) generate graphics
    # to give us quick looks at variability of things like frequency, sentiment, etc over time.  Provides
    # us an at-a-glance look at trends
import datetime
    # Allows me to set search parameters so that I only get each day's tweets and don't have to sort through
    # the old tweets in resultant .csv files
from datetime import date
    # This allows us to name each .csv file with a unique identifier.  That way, when I run the code, instead of
    # overwriting yesterday's tweets, I get a file with today's DTG.
import tweepy
    # We scrape using the Tweepy API
from textblob import TextBlob
    # textblob can be run automatically on each tweet as it is scraped; it is a secondary check on LIWC.  As you've
    # suggested, there probably are better options--but this is the one that I found that worked and was easy for
    # both to comprehend and implement with my skills at the time.

auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_KEY_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)
    # These are all required in order to make the Tweepy API function 

today = date.today()
startDate = datetime.datetime(2020, 2, 20, 0, 0, 0)
endDate = datetime.datetime(2020, 2, 21, 0, 0, 0)
    # This is how I ensure that I am only scraping today's tweets.  I have to manually change the dates
    # every day when I run the program.

csvFile = open(f'#Alt_Right_{today}.csv', 'a')
csvWriter = csv.writer(csvFile)
    # This is how I write the scraped tweets into a .csv file and give it a unique name for each day

hashtags = ['#14Words','#Boogaloo','#ISaluteWhitePeople','#WhiteGenocide','#TCOT','#QAnon']
    # Each control group has its own list, populated with the actionable / practicable hashtags
    # and keywords we uncovered in the process of writing our ideological lit review
    
    # Note: last semester I didn't know how to do this...and so I literally had a Python file for
    # every single individual hashtag.  So instead of running one program for an entire group...
    # I was running about 25 different programs, separated by 15 minutes each.  This is what 
    # I was referencing when I said that the Intro to Python class has really improved efficiency.
  
for i in hashtags:
    # We iterate a for loop to cycle through all of the keywords and hashtags in our hashtag list
    for tweet in tweepy.Cursor(api.search, q=i, count=100000, \
                                                   lang="en", \
                                                   ).items():
        # I am not sure if I formatted this correctly IAW PEP-8...and I also don't think the count
        # object matters or should be set to something.  The point of setting it at 100000 is to 
        # basically make it go until it runs out of material.  In practice, because of the controls
        # imposed by my use of startDate and endDate, every hashtag in my hashtag list gets scraped
        # and never comes close to this limit.
        
        # I don't think the "lang='en'" part matters...in the sense that I don't know if it works
        # or is even essential
        if tweet.created_at < endDate and tweet.created_at > startDate:
            print(tweet.created_at, tweet.text)
            # This if statement is designed to only count tweets with today's date.
            analysis = TextBlob(tweet.text)
            print(analysis.sentiment_assessments)
            # The above two lines of code execute a TextBlob analysis on each tweet and write those results
            # into columns in the .csv file
            csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8'), analysis.polarity, analysis.subjectivity])
            # Final part of the loop is writing everything into the .csv
# Out:
# 2020-02-20 20:16:15 RT @StonehillBirch: #WhitePeople, recognize our racial identity. It’s okay to be White. Become who we are…realize our full potential, again…
# Sentiment(polarity=0.2125, subjectivity=0.5125, assessments=[(['okay'], 0.5, 0.5, None), (['white'], 0.0, 0.0, None), (['full'], 0.35, 0.55, None), (['potential'], 0.0, 1.0, None)])
# 2020-02-20 19:06:39 RT @StonehillBirch: White people should never apologize. Do not apologize to (((them))), and certainly do not apologize to yourself for bei…
# Sentiment(polarity=-0.05357142857142857, subjectivity=0.2857142857142857, assessments=[(['white'], 0.0, 0.0, None), (['certainly', 'not'], -0.10714285714285714, 0.5714285714285714, None)])
# 2020-02-20 10:06:20 WHITE in #Florida. #WhiteSupremacy #PardonTrayvon #FoxNews #FoxAndFriends #MAGA #KKK #14Words #Zimmerman… https://t.co/yFqABjYbrt
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['white'], 0.0, 0.0, None)])
# 2020-02-20 02:58:14 RT @StonehillBirch: #Voting takes a plan:
# ▫️Will you #vote on #ElectionDay⁠ ⁠?
# ▫️What time will you vote?
# ▫️How will you get to the polls?…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#
# /Applications/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# /Applications/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1621         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1622             raise WantReadError()
#    1623         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-642926288071> in <module>
#      47     # We iterate a for loop to cycle through all of the keywords and hashtags in our hashtag list
#      48     for tweet in tweepy.Cursor(api.search, q=i, count=100000, \
# ---> 49                                                    lang="en", \
#      50                                                    ).items():
#      51         # I am not sure if I formatted this correctly IAW PEP-8...and I also don't think the count
#
# /Applications/anaconda3/lib/python3.7/site-packages/tweepy/cursor.py in __next__(self)
#      45
#      46     def __next__(self):
# ---> 47         return self.next()
#      48
#      49     def next(self):
#
# /Applications/anaconda3/lib/python3.7/site-packages/tweepy/cursor.py in next(self)
#     193         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     194             # Reached end of current page, get the next page...
# --> 195             self.current_page = self.page_iterator.next()
#     196             self.page_index = -1
#     197         self.page_index += 1
#
# /Applications/anaconda3/lib/python3.7/site-packages/tweepy/cursor.py in next(self)
#     104
#     105         if self.index >= len(self.results) - 1:
# --> 106             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kargs)
#     107
#     108             if hasattr(self.method, '__self__'):
#
# /Applications/anaconda3/lib/python3.7/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     248                 return method
#     249             else:
# --> 250                 return method.execute()
#     251         finally:
#     252             method.session.close()
#
# /Applications/anaconda3/lib/python3.7/site-packages/tweepy/binder.py in execute(self)
#     187                                                 timeout=self.api.timeout,
#     188                                                 auth=auth,
# --> 189                                                 proxies=self.api.proxy)
#     190                 except Exception as e:
#     191                     six.reraise(TweepError, TweepError('Failed to send request: %s' % e), sys.exc_info()[2])
#
# /Applications/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /Applications/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     684
#     685         if not stream:
# --> 686             r.content
#     687
#     688         return r
#
# /Applications/anaconda3/lib/python3.7/site-packages/requests/models.py in content(self)
#     826                 self._content = None
#     827             else:
# --> 828                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     829
#     830         self._content_consumed = True
#
# /Applications/anaconda3/lib/python3.7/site-packages/requests/models.py in generate()
#     748             if hasattr(self.raw, 'stream'):
#     749                 try:
# --> 750                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     751                         yield chunk
#     752                 except ProtocolError as e:
#
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     492         else:
#     493             while not is_fp_closed(self._fp):
# --> 494                 data = self.read(amt=amt, decode_content=decode_content)
#     495
#     496                 if data:
#
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     440             else:
#     441                 cache_content = False
# --> 442                 data = self._fp.read(amt)
#     443                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     444                     # Close the connection when no data is returned
#
# /Applications/anaconda3/lib/python3.7/http/client.py in read(self, amt)
#     455             # Amount is given, implement using readinto
#     456             b = bytearray(amt)
# --> 457             n = self.readinto(b)
#     458             return memoryview(b)[:n].tobytes()
#     459         else:
#
# /Applications/anaconda3/lib/python3.7/http/client.py in readinto(self, b)
#     499         # connection, and the user is reading more bytes than will be provided
#     500         # (for example, reading in 1k chunks)
# --> 501         n = self.fp.readinto(b)
#     502         if not n and b:
#     503             # Ideally, we would raise IncompleteRead if the content-length
#
# /Applications/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     307                 raise
#     308         except OpenSSL.SSL.WantReadError:
# --> 309             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     310                 raise timeout('The read operation timed out')
#     311             else:
#
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     141     Returns True if the socket is readable, or False if the timeout expired.
#     142     """
# --> 143     return wait_for_socket(sock, read=True, timeout=timeout)
#     144
#     145
#
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     102         return poll_obj.poll(t)
#     103
# --> 104     return bool(_retry_on_intr(do_poll, timeout))
#     105
#     106
#
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      40     # Modern Python, that retries syscalls by default
#      41     def _retry_on_intr(fn, timeout):
# ---> 42         return fn(timeout)
#      43 else:
#      44     # Old and broken Pythons.
#
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in do_poll(t)
#     100         if t is not None:
#     101             t *= 1000
# --> 102         return poll_obj.poll(t)
#     103
#     104     return bool(_retry_on_intr(do_poll, timeout))
#
# KeyboardInterrupt:
