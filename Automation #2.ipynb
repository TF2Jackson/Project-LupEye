# %%
CONSUMER_KEY = 'a19MLVL0NMt7ByLp74Ey0hFN7'
CONSUMER_KEY_SECRET = 'q2KiIFKpwoLqXIIOjNAZ4zEm8h9Vmvwp8X3drcr0WeiLepdJYt'
ACCESS_TOKEN = '1167467648181035008-8PqoqisYZTNwAHxvmd6QqYmH2ztS6a'
ACCESS_TOKEN_SECRET = 'FnXJhL4a50kSTb5Bzr1Ix6cIfnXG6XxvrAPtPU7gmiyal'

import tweepy
import csv
from textblob import TextBlob

auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_KEY_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)

csvFile = open('#WhiteGenocide.csv', 'a')
csvWriter = csv.writer(csvFile)

for tweet in tweepy.Cursor(api.search, q="#WhiteGenocide",  count=100000, \
                           lang="en", \
                           since_id=2019 - 10 - 17).items():
        print(tweet.created_at, tweet.text)
        analysis = TextBlob(tweet.text)
        print(analysis.sentiment_assessments)
        csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8'), analysis.polarity, analysis.subjectivity])
# Out:
# 2020-02-05 19:28:21 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 19:23:02 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 19:19:41 RT @RightStuff47: No one says Asian countries are "too Asian" &amp; need Diversity
#
# No one says Black countries are "too Black" &amp; need Diversit…
# Sentiment(polarity=-0.08333333333333333, subjectivity=0.21666666666666667, assessments=[(['asian'], 0.0, 0.0, None), (['asian'], 0.0, 0.0, None), (['black'], -0.16666666666666666, 0.43333333333333335, None), (['black'], -0.16666666666666666, 0.43333333333333335, None)])
# 2020-02-05 19:16:31 RT @RightStuff47: No one says Asian countries are "too Asian" &amp; need Diversity
#
# No one says Black countries are "too Black" &amp; need Diversit…
# Sentiment(polarity=-0.08333333333333333, subjectivity=0.21666666666666667, assessments=[(['asian'], 0.0, 0.0, None), (['asian'], 0.0, 0.0, None), (['black'], -0.16666666666666666, 0.43333333333333335, None), (['black'], -0.16666666666666666, 0.43333333333333335, None)])
# 2020-02-05 19:13:59 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 19:12:54 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 19:09:13 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 19:02:50 @DigestNo @ScribblesHearts @Nyct0phil3_ Don't touch the binoculars, son! 😬
#
# Secretly, all you #AntiWhites know you'… https://t.co/ZgazEk2nll
# Sentiment(polarity=-0.4, subjectivity=0.7, assessments=[(['secretly'], -0.4, 0.7, None)])
# 2020-02-05 19:00:05 RT @RightStuff47: No one says Asian countries are "too Asian" &amp; need Diversity
#
# No one says Black countries are "too Black" &amp; need Diversit…
# Sentiment(polarity=-0.08333333333333333, subjectivity=0.21666666666666667, assessments=[(['asian'], 0.0, 0.0, None), (['asian'], 0.0, 0.0, None), (['black'], -0.16666666666666666, 0.43333333333333335, None), (['black'], -0.16666666666666666, 0.43333333333333335, None)])
# 2020-02-05 18:59:30 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 18:50:36 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 18:46:11 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 18:38:45 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 18:34:16 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 18:31:55 @Nyct0phil3_ So now you pretend this whole program of immigration and assimilation and chasing down every white on… https://t.co/YqrVLemeV5
# Sentiment(polarity=0.014814814814814808, subjectivity=0.22962962962962963, assessments=[(['whole'], 0.2, 0.4, None), (['down'], -0.15555555555555559, 0.2888888888888889, None), (['white'], 0.0, 0.0, None)])
# 2020-02-05 18:29:06 RT @t_danecki: If whites are forced into a breeding contest in their own countries to survive you're admitting that genocidal policies are…
# Sentiment(polarity=0.14999999999999997, subjectivity=0.6, assessments=[(['forced'], -0.30000000000000004, 0.2, None), (['own'], 0.6, 1.0, None)])
# 2020-02-05 18:26:41 RT @AW_HateWatch: @Nyct0phil3_ @lauraFWG @Sa1nt_Drag0n @_buckfaster @lightbuzzkill @ariacwfaw101 So you're okay with all genocides because…
# Sentiment(polarity=0.5, subjectivity=0.5, assessments=[(['okay'], 0.5, 0.5, None)])
# 2020-02-05 18:25:36 RT @AW_HateWatch: @_buckfaster @lauraFWG @Nyct0phil3_ @Sa1nt_Drag0n @lightbuzzkill @ariacwfaw101 @eyeslevel Lol! 😀 People who can write and…
# Sentiment(polarity=1.0, subjectivity=0.7, assessments=[(['lol', '!'], 1.0, 0.7, None)])
# 2020-02-05 18:24:53 RT @AW_HateWatch: @_buckfaster @lauraFWG @Nyct0phil3_ @Sa1nt_Drag0n @lightbuzzkill @ariacwfaw101 @eyeslevel It's unladylike to use the word…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-05 18:21:14 Stop #WhiteGenocide https://t.co/fPgqDf6qID
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-05 18:20:46 RT @Brerrabbit13: If law enforcement was involved in crime, whistleblowers should report on it.
# If the UN defines genocide &amp; commits it, pr…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-05 18:18:59 @DigestNo @Nyct0phil3_ You're just trolling me with such an absurd question. Do YOU support chattel slavery? Wife-b… https://t.co/Q6hooTg1uP
# Sentiment(polarity=-0.25, subjectivity=0.75, assessments=[(['such'], 0.0, 0.5, None), (['absurd'], -0.5, 1.0, None)])
# 2020-02-05 18:18:42 RT @t_danecki: If whites are forced into a breeding contest in their own countries to survive you're admitting that genocidal policies are…
# Sentiment(polarity=0.14999999999999997, subjectivity=0.6, assessments=[(['forced'], -0.30000000000000004, 0.2, None), (['own'], 0.6, 1.0, None)])
# 2020-02-05 18:17:53 RT @ioannessenator: #Antiwhites are chasing "down" the last white person. #whitegenocide https://t.co/M4dQ5xDcan
# Sentiment(polarity=-0.051851851851851864, subjectivity=0.11851851851851852, assessments=[(['down'], -0.15555555555555559, 0.2888888888888889, None), (['last'], 0.0, 0.06666666666666667, None), (['white'], 0.0, 0.0, None)])
# 2020-02-05 18:17:33 RT @t_danecki: If we're all one race what is "diversity" for?
#
# #WhiteGenocide https://t.co/zYSKzCpKZw
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-05 18:15:29 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 18:08:22 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 18:07:53 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 18:05:20 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 18:03:41 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 18:00:24 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 17:59:12 @DigestNo Dial your IQ up a few points and think about it, #AntiWhite. So that #WhiteGenocide can be carried out wi… https://t.co/168G1q1AFf
# Sentiment(polarity=-0.2, subjectivity=0.1, assessments=[(['few'], -0.2, 0.1, None)])
# 2020-02-05 17:59:06 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 17:52:22 @CGeistman @Nyct0phil3_ Maybe this explains why the #WhiteGenocide cranks are so ugly.
# Sentiment(polarity=-0.7, subjectivity=1.0, assessments=[(['ugly'], -0.7, 1.0, None)])
# 2020-02-05 17:47:48 @DigestNo It's that time-travel chip the #AntiWhite professor slipped into your skull while you were dozing in clas… https://t.co/TDKEdMpyYm
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-05 17:42:47 @Sa1nt_Drag0n @ScribblesHearts @Nyct0phil3_ "Nazi" is a slur that anti-whites hide behind while carrying out White… https://t.co/zNXaZsbGlM
# Sentiment(polarity=-0.4, subjectivity=0.7, assessments=[(['behind'], -0.4, 0.7, None)])
# 2020-02-05 17:42:28 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 17:41:48 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 17:37:05 RT @KoosdlRey: @MmusiMaimane Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universi…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 17:35:31 @DigestNo @Nyct0phil3_ So you support #WhiteGenocide.
# Your excuse is something about the 1850s.
#
# The scary part is… https://t.co/Y53c7ayED7
# Sentiment(polarity=-0.275, subjectivity=0.525, assessments=[(['excuse'], -0.05, 0.05, None), (['scary'], -0.5, 1.0, None)])
# 2020-02-05 17:34:43 RT @AW_HateWatch: @_buckfaster @lauraFWG @Nyct0phil3_ @Sa1nt_Drag0n @lightbuzzkill @ariacwfaw101 @eyeslevel It's unladylike to use the word…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-05 17:32:34 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 17:20:08 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 17:12:10 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 17:09:19 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 17:08:24 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 17:01:48 @Nyct0phil3_ I hate to think ill of a woman. I didn't want to believe that you could be a traitor to your people.
# H… https://t.co/eyAV2wD0Kv
# Sentiment(polarity=-0.65, subjectivity=0.95, assessments=[(['hate'], -0.8, 0.9, None), (['ill'], -0.5, 1.0, None)])
# 2020-02-05 16:59:14 @MmusiMaimane Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our… https://t.co/fcSgLvDEFh
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 16:58:59 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 16:58:54 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 16:56:19 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 16:49:16 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 16:48:14 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 16:48:09 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 16:45:00 @_buckfaster @lauraFWG @Nyct0phil3_ @Sa1nt_Drag0n @lightbuzzkill @ariacwfaw101 @eyeslevel It's unladylike to use th… https://t.co/0IYS5UEOpk
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-05 16:42:45 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 16:39:41 RT @KoosdlRey: @MmusiMaimane Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universi…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 16:37:50 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 16:37:50 #renewables are unreliables &amp; expensive! carbon taxes are all about #whitegenocide . expensive heating bills means… https://t.co/BNvZG6fGCo
# Sentiment(polarity=-0.5625, subjectivity=0.7, assessments=[(['expensive', '!'], -0.625, 0.7, None), (['expensive'], -0.5, 0.7, None)])
# 2020-02-05 16:37:22 #renewables are shitt. solar is shitt.! carbon taxes are all about #whitegenocide . expensive heating bills means m… https://t.co/5uNdchBIOz
# Sentiment(polarity=-0.5, subjectivity=0.7, assessments=[(['expensive'], -0.5, 0.7, None)])
# 2020-02-05 16:36:26 carbon taxes are all about #whitegenocide . expensive heating bills means more deaths in #grandsolarminimum cold ic… https://t.co/HUoWfyfXPc
# Sentiment(polarity=-0.19999999999999998, subjectivity=0.7333333333333334, assessments=[(['expensive'], -0.5, 0.7, None), (['more'], 0.5, 0.5, None), (['cold'], -0.6, 1.0, None)])
# 2020-02-05 16:33:59 @Nyct0phil3_ @lauraFWG @_buckfaster @Sa1nt_Drag0n @lightbuzzkill @ariacwfaw101 @eyeslevel You are a font of wonderf… https://t.co/qXD5uK4ks3
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-05 16:30:31 What a difference Milo makes
#
# #AustraliaBushfires #AustraliaBurning #AustraliaBurns #AustralianFires… https://t.co/BvWuAIPAzG
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-05 16:26:15 @LouiseRawAuthor @Nyct0phil3_ @lauraFWG @lightbuzzkill @ariacwfaw101 Why would you count for two? Are you a very sp… https://t.co/MccjpJmVMK
# Sentiment(polarity=0.2, subjectivity=0.3, assessments=[(['very'], 0.2, 0.3, None)])
# 2020-02-05 16:26:09 They’re lying about our past, ethnically cleansing it in order to facilitate the cultural and biological genocide o… https://t.co/yskTT5YDBb
# Sentiment(polarity=-0.075, subjectivity=0.175, assessments=[(['past'], -0.25, 0.25, None), (['cultural'], 0.1, 0.1, None)])
# 2020-02-05 16:25:38 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 16:23:21 RT @KoosdlRey: @MmusiMaimane Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universi…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 16:20:12 RT @KoosdlRey: @MmusiMaimane Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universi…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 16:19:11 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 16:14:27 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 16:01:07 #AntiWhites deny #WhiteGenocide, then they laugh about it. https://t.co/1axcCKfKp7
# Sentiment(polarity=0.3, subjectivity=0.1, assessments=[(['laugh'], 0.3, 0.1, None)])
# 2020-02-05 15:58:00 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 15:55:58 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 15:55:30 @MmusiMaimane Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our… https://t.co/6Otn3IWhY7
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 15:55:02 @_buckfaster @Nyct0phil3_ @lauraFWG @Sa1nt_Drag0n @lightbuzzkill @ariacwfaw101 William Shockley, Charles Lindbergh.… https://t.co/PRoLIkL5ED
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-05 15:54:03 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 15:48:21 #AntiWhites dodge questions about #WhiteGenocide by engaging in ad hominem attacks or changing the subject. https://t.co/5oo6hVxn9z
# Sentiment(polarity=0.11666666666666668, subjectivity=0.5166666666666666, assessments=[(['engaging'], 0.4, 0.7, None), (['subject'], -0.16666666666666666, 0.3333333333333333, None)])
# 2020-02-05 15:48:08 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 15:48:06 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 15:46:20 Happy Little Vegemite
#
# #AustraliaBushfires #AustraliaBurning #AustraliaBurns #AustralianFires #AUSTRALIANBUSHFIRES… https://t.co/511Hwd4HBz
# Sentiment(polarity=0.30625, subjectivity=0.75, assessments=[(['happy'], 0.8, 1.0, None), (['little'], -0.1875, 0.5, None)])
# 2020-02-05 15:45:48 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 15:45:02 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 15:43:16 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 15:41:37 @steveTbone @Nyct0phil3_ @t_danecki I never said it was the people themselves, it’s your leftist Marxist media , ac… https://t.co/vrUU8HkUoS
# Sentiment(polarity=-0.05, subjectivity=0.6, assessments=[(['leftist'], -0.05, 0.6, None)])
# 2020-02-05 15:40:14 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 15:39:34 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 15:39:09 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 15:38:51 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 15:38:49 RT @RightStuff47: #AntiWhites have no problem with Asian countries remaining Asian &amp; Black countries remaining Black.
#
# #AntiWhites single o…
# Sentiment(polarity=-0.08095238095238096, subjectivity=0.21619047619047618, assessments=[(['asian'], 0.0, 0.0, None), (['asian'], 0.0, 0.0, None), (['black'], -0.16666666666666666, 0.43333333333333335, None), (['black'], -0.16666666666666666, 0.43333333333333335, None), (['single'], -0.07142857142857142, 0.21428571428571427, None)])
# 2020-02-05 15:38:16 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 15:37:53 RT @AW_HateWatch: @_buckfaster @lauraFWG @Nyct0phil3_ @Sa1nt_Drag0n @lightbuzzkill @ariacwfaw101 @eyeslevel Lol! 😀 People who can write and…
# Sentiment(polarity=1.0, subjectivity=0.7, assessments=[(['lol', '!'], 1.0, 0.7, None)])
# 2020-02-05 15:37:25 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 15:36:53 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 15:36:31 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 15:36:12 #AntiWhites have no problem with Asian countries remaining Asian &amp; Black countries remaining Black.
#
# #AntiWhites si… https://t.co/JKdqZPxAfl
# Sentiment(polarity=-0.08333333333333333, subjectivity=0.21666666666666667, assessments=[(['asian'], 0.0, 0.0, None), (['asian'], 0.0, 0.0, None), (['black'], -0.16666666666666666, 0.43333333333333335, None), (['black'], -0.16666666666666666, 0.43333333333333335, None)])
# 2020-02-05 15:35:04 @_buckfaster @lauraFWG @Nyct0phil3_ @Sa1nt_Drag0n @lightbuzzkill @ariacwfaw101 @eyeslevel Lol! 😀 People who can wri… https://t.co/GMtanXVQTv
# Sentiment(polarity=1.0, subjectivity=0.7, assessments=[(['lol', '!'], 1.0, 0.7, None)])
# 2020-02-05 15:34:52 I like Aeroplane Jelly
#
# #AustraliaBushfires #AustraliaBurning #AustraliaBurns #AustralianFires #AUSTRALIANBUSHFIRES… https://t.co/BHUWrrmyaI
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-05 15:33:33 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 15:33:23 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 15:33:15 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 15:33:13 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 15:32:08 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 15:31:07 RT @KoosdlRey: Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities taken
# -Ou…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 15:29:11 Here is mine:
# -We are being killed
# -Our land taken
# -Our language attacked
# -Our religion attacked
# -Our universities… https://t.co/Qb5Dy754X1
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['killed'], -0.2, 0.0, None)])
# 2020-02-05 15:27:50 @_buckfaster @Nyct0phil3_ @lauraFWG @Sa1nt_Drag0n @lightbuzzkill @ariacwfaw101 #AntiWhites who support… https://t.co/q59c6yM4me
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-05 15:25:57 RT @RightStuff47: If Diversity is such a strength why does it ALWAYS have to be forced?
#
# Why is Diversity ALWAYS forced on White countries…
# Sentiment(polarity=-0.15000000000000002, subjectivity=0.22499999999999998, assessments=[(['such'], 0.0, 0.5, None), (['forced'], -0.30000000000000004, 0.2, None), (['forced'], -0.30000000000000004, 0.2, None), (['white'], 0.0, 0.0, None)])
# 2020-02-05 15:24:58 RT @RightStuff47: If you are White &amp; support Diversity you're a self hating White.
#
# Diversity means chasing down the last White person.
#
# Di…
# Sentiment(polarity=-0.031111111111111117, subjectivity=0.07111111111111111, assessments=[(['white'], 0.0, 0.0, None), (['white'], 0.0, 0.0, None), (['down'], -0.15555555555555559, 0.2888888888888889, None), (['last'], 0.0, 0.06666666666666667, None), (['white'], 0.0, 0.0, None)])
# 2020-02-05 15:23:48 RT @AW_HateWatch: @Nyct0phil3_ @lauraFWG @Sa1nt_Drag0n @_buckfaster @lightbuzzkill @ariacwfaw101 So you're okay with all genocides because…
# Sentiment(polarity=0.5, subjectivity=0.5, assessments=[(['okay'], 0.5, 0.5, None)])
# 2020-02-05 15:23:05 If #WhiteGenocide is "a f**king nonsense" exactly which countries are allowed to remain White? https://t.co/faqymDyjKE
# Sentiment(polarity=0.125, subjectivity=0.125, assessments=[(['exactly'], 0.25, 0.25, None), (['white'], 0.0, 0.0, None)])
# 2020-02-05 15:16:46 @Nyct0phil3_ @steveTbone @t_danecki Anti-racist is just code for #whitegenocide. Why is non white immigration only… https://t.co/JQxKvDWxX3
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['white'], 0.0, 0.0, None)])
# 2020-02-05 15:15:36 @Nyct0phil3_ @lauraFWG @Sa1nt_Drag0n @_buckfaster @lightbuzzkill @ariacwfaw101 So you're okay with all genocides be… https://t.co/IcPAwoC9GS
# Sentiment(polarity=0.5, subjectivity=0.5, assessments=[(['okay'], 0.5, 0.5, None)])
# 2020-02-05 15:09:53 If you are White &amp; support Diversity you're a self hating White.
#
# Diversity means chasing down the last White perso… https://t.co/72Mb4tJ4pk
# Sentiment(polarity=-0.031111111111111117, subjectivity=0.07111111111111111, assessments=[(['white'], 0.0, 0.0, None), (['white'], 0.0, 0.0, None), (['down'], -0.15555555555555559, 0.2888888888888889, None), (['last'], 0.0, 0.06666666666666667, None), (['white'], 0.0, 0.0, None)])
# 2020-02-05 15:08:56 Aussie kids are Weet-Bix kids
#
# #AustraliaBushfires #AustraliaBurning #AustraliaBurns #AustralianFires… https://t.co/0ebpYD1ZcS
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-05 15:04:15 RT @RightStuff47: No one says Asian countries are "too Asian" &amp; need Diversity
#
# No one says Black countries are "too Black" &amp; need Diversit…
# Sentiment(polarity=-0.08333333333333333, subjectivity=0.21666666666666667, assessments=[(['asian'], 0.0, 0.0, None), (['asian'], 0.0, 0.0, None), (['black'], -0.16666666666666666, 0.43333333333333335, None), (['black'], -0.16666666666666666, 0.43333333333333335, None)])
# 2020-02-05 14:57:31 RT @AW_HateWatch: @RyLiberty Ideological cohesion is tenuous, since ideologies can and do change. Biological #identity is fixed, until #Ant…
# Sentiment(polarity=0.1, subjectivity=0.2, assessments=[(['fixed'], 0.1, 0.2, None)])
# 2020-02-05 14:50:47 RT @RightStuff47: If Diversity is such a strength why does it ALWAYS have to be forced?
#
# Why is Diversity ALWAYS forced on White countries…
# Sentiment(polarity=-0.15000000000000002, subjectivity=0.22499999999999998, assessments=[(['such'], 0.0, 0.5, None), (['forced'], -0.30000000000000004, 0.2, None), (['forced'], -0.30000000000000004, 0.2, None), (['white'], 0.0, 0.0, None)])
# 2020-02-05 14:50:35 @ZA_Rebel They should have negotiated a white only independent state but that's not what the #NewWorldOrder wanted… https://t.co/UE21Z9IwXf
# Sentiment(polarity=0.0, subjectivity=0.375, assessments=[(['white'], 0.0, 0.0, None), (['only'], 0.0, 1.0, None), (['independent'], 0.0, 0.125, None)])
# 2020-02-05 14:50:29 If Diversity is such a strength why does it ALWAYS have to be forced?
#
# Why is Diversity ALWAYS forced on White coun… https://t.co/C4PAhn9Rib
# Sentiment(polarity=-0.15000000000000002, subjectivity=0.22499999999999998, assessments=[(['such'], 0.0, 0.5, None), (['forced'], -0.30000000000000004, 0.2, None), (['forced'], -0.30000000000000004, 0.2, None), (['white'], 0.0, 0.0, None)])
# 2020-02-05 14:45:50 RT @RightStuff47: Just another night of Diversity chasing down the last White Londoner.
#
# Diversity is a code word for #WhiteGenocide. https…
# Sentiment(polarity=-0.051851851851851864, subjectivity=0.11851851851851852, assessments=[(['down'], -0.15555555555555559, 0.2888888888888889, None), (['last'], 0.0, 0.06666666666666667, None), (['white'], 0.0, 0.0, None)])
# 2020-02-05 14:43:50 RT @RightStuff47: No one says Asian countries are "too Asian" &amp; need Diversity
#
# No one says Black countries are "too Black" &amp; need Diversit…
# Sentiment(polarity=-0.08333333333333333, subjectivity=0.21666666666666667, assessments=[(['asian'], 0.0, 0.0, None), (['asian'], 0.0, 0.0, None), (['black'], -0.16666666666666666, 0.43333333333333335, None), (['black'], -0.16666666666666666, 0.43333333333333335, None)])
# 2020-02-05 14:43:10 RT @RightStuff47: No one says Asian countries are "too Asian" &amp; need Diversity
#
# No one says Black countries are "too Black" &amp; need Diversit…
# Sentiment(polarity=-0.08333333333333333, subjectivity=0.21666666666666667, assessments=[(['asian'], 0.0, 0.0, None), (['asian'], 0.0, 0.0, None), (['black'], -0.16666666666666666, 0.43333333333333335, None), (['black'], -0.16666666666666666, 0.43333333333333335, None)])
# 2020-02-05 14:41:38 RT @RightStuff47: No one says Asian countries are "too Asian" &amp; need Diversity
#
# No one says Black countries are "too Black" &amp; need Diversit…
# Sentiment(polarity=-0.08333333333333333, subjectivity=0.21666666666666667, assessments=[(['asian'], 0.0, 0.0, None), (['asian'], 0.0, 0.0, None), (['black'], -0.16666666666666666, 0.43333333333333335, None), (['black'], -0.16666666666666666, 0.43333333333333335, None)])
# 2020-02-05 14:41:12 No one says Asian countries are "too Asian" &amp; need Diversity
#
# No one says Black countries are "too Black" &amp; need Di… https://t.co/OrQchK7ylF
# Sentiment(polarity=-0.08333333333333333, subjectivity=0.21666666666666667, assessments=[(['asian'], 0.0, 0.0, None), (['asian'], 0.0, 0.0, None), (['black'], -0.16666666666666666, 0.43333333333333335, None), (['black'], -0.16666666666666666, 0.43333333333333335, None)])
# 2020-02-05 14:28:53 RT @t_danecki: ONLY white people are expected and urged to believe that "we're all one race".
#
# The preachers of "equality" have in actualit…
# Sentiment(polarity=-0.03333333333333333, subjectivity=0.4666666666666666, assessments=[(['only'], 0.0, 1.0, None), (['white'], 0.0, 0.0, None), (['expected'], -0.1, 0.4, None)])
# 2020-02-05 14:28:34 RT @AW_HateWatch: @RayRahmanNYC @lauraFWG @lightbuzzkill @RodneyRecloose @Fight_Progress Reality for you is what media and governments tell…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-05 14:24:43 RT @AW_HateWatch: @RayRahmanNYC @lauraFWG @lightbuzzkill @RodneyRecloose @Fight_Progress Reality for you is what media and governments tell…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-05 14:23:11 RT @AW_HateWatch: @RayRahmanNYC @lauraFWG @lightbuzzkill @RodneyRecloose @Fight_Progress Reality for you is what media and governments tell…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-05 14:21:16 @RayRahmanNYC @lauraFWG @lightbuzzkill @RodneyRecloose @Fight_Progress Reality for you is what media and government… https://t.co/WU5fLnHeFW
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-05 14:13:01 Just another night of Diversity chasing down the last White Londoner.
#
# Diversity is a code word for #WhiteGenocide. https://t.co/RwfkTNgdX2
# Sentiment(polarity=-0.051851851851851864, subjectivity=0.11851851851851852, assessments=[(['down'], -0.15555555555555559, 0.2888888888888889, None), (['last'], 0.0, 0.06666666666666667, None), (['white'], 0.0, 0.0, None)])
# 2020-02-05 14:11:40 @Nyct0phil3_ Assimilation IS Genocide.
#
# Flood ALL white countries with millions of non-whites, then force integrat… https://t.co/gvvfLppn2Q
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['white'], 0.0, 0.0, None)])
# 2020-02-05 14:10:57 ANYTHING that's "too White" is a "problem" &amp; needs Diversity.
#
# Diversity means chasing down the last White person i… https://t.co/RBOfc1LnKv
# Sentiment(polarity=-0.038888888888888896, subjectivity=0.08888888888888889, assessments=[(['white'], 0.0, 0.0, None), (['down'], -0.15555555555555559, 0.2888888888888889, None), (['last'], 0.0, 0.06666666666666667, None), (['white'], 0.0, 0.0, None)])
# 2020-02-05 14:07:11 #AntiWhites deny #WhiteGenocide, then they enable it. https://t.co/LJuVIn3yLt
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-05 14:07:06 @amnesty Start preparing the briefs for #criminals like yourselves who are carrying out #WhiteGenocide. https://t.co/YIGduzaLov
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-05 14:05:45 RT @t_danecki: Anti-whites demand "diversity" in ONLY white countries.
#
# #WhiteGenocide https://t.co/lvoC8kLF0E
# Sentiment(polarity=0.0, subjectivity=0.5, assessments=[(['only'], 0.0, 1.0, None), (['white'], 0.0, 0.0, None)])
# 2020-02-05 14:04:53 #AntiWhites deny #WhiteGenocide, then brag about our "inevitable" brown future. https://t.co/d0sBeU3RSp
# Sentiment(polarity=0.0, subjectivity=0.5625, assessments=[(['inevitable'], 0.0, 1.0, None), (['future'], 0.0, 0.125, None)])
# 2020-02-05 14:03:16 RT @t_danecki: If "diversity" is so great why is it for ONLY white countries?
#
# #WhiteGenocide https://t.co/kv2ZSvQqSI
# Sentiment(polarity=0.26666666666666666, subjectivity=0.5833333333333334, assessments=[(['great'], 0.8, 0.75, None), (['only'], 0.0, 1.0, None), (['white'], 0.0, 0.0, None)])
# 2020-02-05 14:01:57 @_buckfaster @Nyct0phil3_ @lightbuzzkill @ariacwfaw101 Says the one to chicken to show face.
#
# #WhiteGenocide
# Sentiment(polarity=-0.6, subjectivity=0.95, assessments=[(['chicken'], -0.6, 0.95, None)])
# 2020-02-05 13:47:27 #MakeIrelandWhiteAgain. Will #TheCrown command the #Loyalists to come back home to #Britain and offer them a better… https://t.co/PYIu0T9eol
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['back'], 0.0, 0.0, None)])
# 2020-02-05 13:40:55 @RyLiberty Ideological cohesion is tenuous, since ideologies can and do change. Biological #identity is fixed, unti… https://t.co/fRxF7B4nlQ
# Sentiment(polarity=0.1, subjectivity=0.2, assessments=[(['fixed'], 0.1, 0.2, None)])
# 2020-02-05 12:37:30 Now do DJs who care about issues like #FreeSpeech #itsokaytobewhite #WhiteGenocide #ChildRapeGangs… https://t.co/K9FtVuGhbm
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-05 12:29:44 RT @AndyGraves80: #Frexit #Brexit LEAVE THE #KALERGIPLAN... Europe for EUROPEANS!!!! #EU is enforcing #WhiteGenocide We must rise against t…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-05 12:21:25 @Nyct0phil3_ @lightbuzzkill @ariacwfaw101 You've heard of the term "white flight"?
#
# "Diversity" is forced on anyth… https://t.co/XbwkHM9kGB
# Sentiment(polarity=-0.15000000000000002, subjectivity=0.1, assessments=[(['white'], 0.0, 0.0, None), (['forced'], -0.30000000000000004, 0.2, None)])
# 2020-02-05 12:09:43 What is "real"?
#
# #AustraliaBushfires #AustraliaBurning #AustraliaBurns #AustralianFires #AUSTRALIANBUSHFIRES… https://t.co/dmVpqqaiIF
# Sentiment(polarity=0.2, subjectivity=0.30000000000000004, assessments=[(['real'], 0.2, 0.30000000000000004, None)])
# 2020-02-05 10:46:04 @irish_thorn @ed_unwa @naughtypadfa @thisislaurat @LivesMorgoth @MarkACollett @melvyn_waters @ShereeJasmine1… https://t.co/vXJXp0BQi9
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-05 09:57:59 #multiculture #diversity all are codewords for  #whitegenocide ... #whitemales be aware 😅😀 . socialists steal all y… https://t.co/Q59R8KKH0f
# Sentiment(polarity=0.25, subjectivity=0.25, assessments=[(['aware'], 0.25, 0.25, None)])
# 2020-02-05 09:30:02 RT @Anthony__Brass: Rush Limbaugh’s Most Racist Quotes: A Timeline Of Destructive Commentary:  https://t.co/6hpBnkIRCE
#
# #tcot #BuildTheWall…
# Sentiment(polarity=-0.04999999999999999, subjectivity=0.55, assessments=[(['most'], 0.5, 0.5, None), (['destructive'], -0.6, 0.6, None)])
# 2020-02-05 09:28:31 RT @Anthony__Brass: Rush Limbaugh’s Most Racist Quotes: A Timeline Of Destructive Commentary:  https://t.co/6hpBnkIRCE
#
# #tcot #BuildTheWall…
# Sentiment(polarity=-0.04999999999999999, subjectivity=0.55, assessments=[(['most'], 0.5, 0.5, None), (['destructive'], -0.6, 0.6, None)])
# 2020-02-05 09:27:10 Rush Limbaugh’s Most Racist Quotes: A Timeline Of Destructive Commentary:  https://t.co/6hpBnkIRCE
#
# #tcot… https://t.co/DC9cqMqAfX
# Sentiment(polarity=-0.04999999999999999, subjectivity=0.55, assessments=[(['most'], 0.5, 0.5, None), (['destructive'], -0.6, 0.6, None)])
# 2020-02-05 09:27:03 Rush Limbaugh’s Most Racist Quotes: A Timeline Of Destructive Commentary:  https://t.co/5gsqjqsl1m
#
# #tcot… https://t.co/30Ac0Envwi
# Sentiment(polarity=-0.04999999999999999, subjectivity=0.55, assessments=[(['most'], 0.5, 0.5, None), (['destructive'], -0.6, 0.6, None)])
# 2020-02-05 08:13:54 RT @lightbuzzkill: @ariacwfaw101 @lauraFWG @ariacwfaw101 @lauraFWG
#
# you poor poor oppressed pants-shitting victims of nasty #antiwhite bul…
# Sentiment(polarity=-0.6, subjectivity=0.7333333333333334, assessments=[(['poor'], -0.4, 0.6, None), (['poor'], -0.4, 0.6, None), (['nasty'], -1.0, 1.0, None)])
# 2020-02-05 07:55:43 RT @lightbuzzkill: @ariacwfaw101 @lauraFWG @ariacwfaw101 @lauraFWG
#
# you poor poor oppressed pants-shitting victims of nasty #antiwhite bul…
# Sentiment(polarity=-0.6, subjectivity=0.7333333333333334, assessments=[(['poor'], -0.4, 0.6, None), (['poor'], -0.4, 0.6, None), (['nasty'], -1.0, 1.0, None)])
# 2020-02-05 06:29:38 RT @reenasharma38: #greentyranny #ecofascist plan is to ban diesel oil gas woods coals - destroy life standard of white nations and make th…
# Sentiment(polarity=-0.06666666666666667, subjectivity=0.0, assessments=[(['destroy'], -0.2, 0.0, None), (['standard'], 0.0, 0.0, None), (['white'], 0.0, 0.0, None)])
# 2020-02-05 06:21:12 #greentyranny #ecofascist plan is to ban diesel oil gas woods coals - destroy life standard of white nations and ma… https://t.co/WxjLRBCjEK
# Sentiment(polarity=-0.06666666666666667, subjectivity=0.0, assessments=[(['destroy'], -0.2, 0.0, None), (['standard'], 0.0, 0.0, None), (['white'], 0.0, 0.0, None)])
# 2020-02-05 06:11:58 RT @lauraFWG: @TheWesternldeaI @LadyAodh What she is saying is that Iowa is "too white" and it needs to be chased down with "diversity", so…
# Sentiment(polarity=-0.07777777777777779, subjectivity=0.14444444444444446, assessments=[(['white'], 0.0, 0.0, None), (['down'], -0.15555555555555559, 0.2888888888888889, None)])
# 2020-02-05 05:42:55 3 *more* industrial fires start simultaneously in Melbourne (not adjacent buildings)
#
# Wake up Australia! This is WA… https://t.co/g43IFV24Ym
# Sentiment(polarity=0.625, subjectivity=0.5, assessments=[(['more', '!'], 0.625, 0.5, None)])
# 2020-02-05 04:24:47 RT @lauraFWG: What she is saying is that Iowa is "too white" and it needs to be chased down with "diversity", so that it becomes DIVERSE, w…
# Sentiment(polarity=-0.07777777777777779, subjectivity=0.14444444444444446, assessments=[(['white'], 0.0, 0.0, None), (['down'], -0.15555555555555559, 0.2888888888888889, None)])
# 2020-02-05 04:06:19 If "diversity" is so great why is it for ONLY white countries?
#
# #WhiteGenocide https://t.co/kv2ZSvQqSI
# Sentiment(polarity=0.26666666666666666, subjectivity=0.5833333333333334, assessments=[(['great'], 0.8, 0.75, None), (['only'], 0.0, 1.0, None), (['white'], 0.0, 0.0, None)])
# 2020-02-05 04:01:55 @RayRahmanNYC Does "diversity" mean more white people or only FEWER?
#
# #WhiteGenocide
# Sentiment(polarity=0.046875, subjectivity=0.546875, assessments=[(['mean'], -0.3125, 0.6875, None), (['more'], 0.5, 0.5, None), (['white'], 0.0, 0.0, None), (['only'], 0.0, 1.0, None)])
# 2020-02-05 03:55:15 Anti-whites demand "diversity" in ONLY white countries.
#
# #WhiteGenocide https://t.co/lvoC8kLF0E
# Sentiment(polarity=0.0, subjectivity=0.5, assessments=[(['only'], 0.0, 1.0, None), (['white'], 0.0, 0.0, None)])
# 2020-02-05 03:44:07 RT @t_danecki: Denial has been an integral part of each stage in every genocide in history.
#
# #WhiteGenocide https://t.co/MBQpAvpnhp
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-05 03:40:51 RT @t_danecki: Any white person who doesn't want his race abolished is a "nazi prat".
#
# "Anti-nazi" is a code word for anti-white.
#
# #WhiteGe…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['white'], 0.0, 0.0, None)])
# 2020-02-05 03:24:42 RT @StonehillBirch: #Whites in America would be wise to remember that the United States was originally conceived, created, and codified by…
# Sentiment(polarity=0.5375, subjectivity=0.825, assessments=[(['wise'], 0.7, 0.9, None), (['originally'], 0.375, 0.75, None)])
# 2020-02-05 03:22:14 RT @StonehillBirch: The United States of America was indeed founded as a White country—an extension of British, European, Scandinavian heri…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['white'], 0.0, 0.0, None), (['british'], 0.0, 0.0, None), (['european'], 0.0, 0.0, None)])
# 2020-02-05 03:13:05 RT @t_danecki: ONLY white people are expected and urged to believe that "we're all one race".
#
# The preachers of "equality" have in actualit…
# Sentiment(polarity=-0.03333333333333333, subjectivity=0.4666666666666666, assessments=[(['only'], 0.0, 1.0, None), (['white'], 0.0, 0.0, None), (['expected'], -0.1, 0.4, None)])
# 2020-02-05 03:12:39 RT @t_danecki: Violence is not a requirement for a genocide to occur, you #AntiWhite liar.
#
# #WhiteGenocide https://t.co/09wCVlzYzG
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-05 03:05:01 RT @lauraFWG: What she is saying is that Iowa is "too white" and it needs to be chased down with "diversity", so that it becomes DIVERSE, w…
# Sentiment(polarity=-0.07777777777777779, subjectivity=0.14444444444444446, assessments=[(['white'], 0.0, 0.0, None), (['down'], -0.15555555555555559, 0.2888888888888889, None)])
# 2020-02-05 03:00:32 RT @RightStuff47: Demoralizing Whites with self hatred was the first step #AntiWhites used toward the goal of #WhiteGenocide.
#
# White self h…
# Sentiment(polarity=0.125, subjectivity=0.16666666666666666, assessments=[(['first'], 0.25, 0.3333333333333333, None), (['white'], 0.0, 0.0, None)])
# 2020-02-05 02:55:44 @ariacwfaw101 @lauraFWG @ariacwfaw101 @lauraFWG
#
# you poor poor oppressed pants-shitting victims of nasty… https://t.co/6EKSkLMmrI
# Sentiment(polarity=-0.4, subjectivity=0.6, assessments=[(['poor'], -0.4, 0.6, None), (['poor'], -0.4, 0.6, None)])
# 2020-02-05 02:47:03 RT @StonehillBirch: Why Leftists are keen to keep letting in unfettered hordes of non-White #IllegalAliens into White, Western nations:
#
# ht…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['white'], 0.0, 0.0, None), (['western'], 0.0, 0.0, None)])
# 2020-02-05 02:42:34 RT @lauraFWG: What she is saying is that Iowa is "too white" and it needs to be chased down with "diversity", so that it becomes DIVERSE, w…
# Sentiment(polarity=-0.07777777777777779, subjectivity=0.14444444444444446, assessments=[(['white'], 0.0, 0.0, None), (['down'], -0.15555555555555559, 0.2888888888888889, None)])
# 2020-02-05 02:42:31 RT @t_danecki: Exactly which countries should remain white?
#
# #WhiteGenocide
# Sentiment(polarity=0.125, subjectivity=0.125, assessments=[(['exactly'], 0.25, 0.25, None), (['white'], 0.0, 0.0, None)])
# 2020-02-05 02:35:40 RT @t_danecki: Any white person who doesn't want his race abolished is a "nazi prat".
#
# "Anti-nazi" is a code word for anti-white.
#
# #WhiteGe…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['white'], 0.0, 0.0, None)])
# 2020-02-05 02:35:08 RT @t_danecki: What exactly IS the difference between forcing Jews into concetration camps to gas them and forcing whites into "melting pot…
# Sentiment(polarity=0.25, subjectivity=0.25, assessments=[(['exactly'], 0.25, 0.25, None)])
# 2020-02-05 02:32:46 RT @t_danecki: Violence is not a requirement for a genocide to occur, you #AntiWhite liar.
#
# #WhiteGenocide https://t.co/vRB4X4W8vy https://…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-02-05 02:32:07 RT @StonehillBirch: #Whites in America would be wise to remember that the United States was originally conceived, created, and codified by…
# Sentiment(polarity=0.5375, subjectivity=0.825, assessments=[(['wise'], 0.7, 0.9, None), (['originally'], 0.375, 0.75, None)])
# 2020-02-05 02:31:02 @Xenophon_0000 @guardian @Xenophon_0000
#
# hi danecki
#
# ...
# 2020-01-29 10:06:27 RT @t_danecki: Asia for the Asians.
# Africa for the Africans.
#
# White countries for EVERYBODY, or you're a "fascist"!
#
# "Anti-fascist" is a co…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['white', '!'], 0.0, 0.0, None)])
# 2020-01-29 10:05:16 RT @t_danecki: No forced "diversity"=no race war.
#
# #WhiteGenocide https://t.co/ghC9zkOdLs
# Sentiment(polarity=0.15000000000000002, subjectivity=0.2, assessments=[(['no', 'forced'], 0.15000000000000002, 0.2, None)])
# 2020-01-29 10:04:56 RT @lauraFWG: President #Trump,
#
# I want to know how you're going to save My race, the White race, from #Genocide ?
#
# Assimilation is genoc…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['white'], 0.0, 0.0, None)])
# 2020-01-29 10:04:14 RT @RightStuff47: ANYTHING "too White" ALWAYS needs Diversity.
# Diversity means chasing down the last White Oscar winner.
# Diversity is a cod…
# Sentiment(polarity=-0.038888888888888896, subjectivity=0.08888888888888889, assessments=[(['white'], 0.0, 0.0, None), (['down'], -0.15555555555555559, 0.2888888888888889, None), (['last'], 0.0, 0.06666666666666667, None), (['white'], 0.0, 0.0, None)])
# 2020-01-29 10:03:27 RT @AW_HateWatch: 70 white students learn to hate themselves by finding the "Nasty Little Racist Inside Them."
#
# #WhiteGenocide by mass immi…
# Sentiment(polarity=-0.496875, subjectivity=0.6, assessments=[(['white'], 0.0, 0.0, None), (['hate'], -0.8, 0.9, None), (['nasty'], -1.0, 1.0, None), (['little'], -0.1875, 0.5, None)])
# 2020-01-29 09:46:11 @SteveRightNLeft You gleefully stated that we are all going to be coffee coloured through race mixing then let out… https://t.co/xJqteK0XFf
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-01-29 09:31:12 RT @VonPilsner: it's incredible when you think about it lol
#
# we are paying taxes to fund our own replacement
#
# has there ever been a bigger…
# Sentiment(polarity=0.7666666666666667, subjectivity=0.8666666666666667, assessments=[(['incredible'], 0.9, 0.9, None), (['lol'], 0.8, 0.7, None), (['own'], 0.6, 1.0, None)])
# 2020-01-29 09:24:06 RT @Xenophon_0000: @NBCNewsNow In 300 years:
#
# Asia will remain Asian,
# Africa will remain African,
#
# Only White countries are expected to op…
# Sentiment(polarity=-0.02, subjectivity=0.27999999999999997, assessments=[(['asian'], 0.0, 0.0, None), (['african'], 0.0, 0.0, None), (['only'], 0.0, 1.0, None), (['white'], 0.0, 0.0, None), (['expected'], -0.1, 0.4, None)])
# 2020-01-29 09:21:41 RT @Xenophon_0000: @HuffPost Turning ALL White countries &amp; ONLY White countries into #Diverse melting pots will cause Whites to eventually…
# Sentiment(polarity=0.0, subjectivity=0.3333333333333333, assessments=[(['white'], 0.0, 0.0, None), (['only'], 0.0, 1.0, None), (['white'], 0.0, 0.0, None)])
# 2020-01-29 09:18:36 70 white students learn to hate themselves by finding the "Nasty Little Racist Inside Them."
#
# #WhiteGenocide by mas… https://t.co/4wDUOgywwr
# Sentiment(polarity=-0.496875, subjectivity=0.6, assessments=[(['white'], 0.0, 0.0, None), (['hate'], -0.8, 0.9, None), (['nasty'], -1.0, 1.0, None), (['little'], -0.1875, 0.5, None)])
# 2020-01-29 09:17:57 RT @MikeBak47552427: #Feminazi Verena Brunschweiger is telling Germans to stop having babies to save the planet, despite the fact that Germ…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-01-29 09:16:50 RT @ariacwfaw101: "Diversity" is a codeword for #WhiteGenocide
#
# #vape #vaporwave https://t.co/KZYZ6rvpiQ
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-01-29 08:49:23 South Africa must be the only country in the world where the “victims of genocide” pay the perpetrators of the so c… https://t.co/PSwbfjZT3u
# Sentiment(polarity=0.0, subjectivity=1.0, assessments=[(['only'], 0.0, 1.0, None)])
# 2020-01-29 07:40:05 Isn't this Jewish DIVERSITY just a paraphrase of erotomania? It's a queer idea to overdo sexual intercourse with in… https://t.co/ah20ZXNrAM
# Sentiment(polarity=0.25, subjectivity=0.4166666666666667, assessments=[(['jewish'], 0.0, 0.0, None), (['sexual'], 0.5, 0.8333333333333334, None)])
# 2020-01-29 07:38:32 RT @MinoritySave: @BasedPoland @Catherine_LCP Mass migration of Africans and Muslims is destroying Europe ‼️
#
# #Agenda21 #newworldorder #Whi…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['destroying'], -0.2, 0.0, None)])
# 2020-01-29 07:00:24 @crowfather1 @toryboypierce It would be a good excuse for more immigration #WhiteGenocide
# Sentiment(polarity=0.3833333333333333, subjectivity=0.38333333333333336, assessments=[(['good'], 0.7, 0.6000000000000001, None), (['excuse'], -0.05, 0.05, None), (['more'], 0.5, 0.5, None)])
# 2020-01-29 06:07:20 RT @EuropeanRevolt: Shoah'd (from Twitter) footage of White South Africans under threat of genocide  preparing for coming conflict. #AntiWh…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['white'], 0.0, 0.0, None)])
# 2020-01-29 05:48:39 RT @MinoritySave: @BasedPoland @Catherine_LCP Mass migration of Africans and Muslims is destroying Europe ‼️
#
# #Agenda21 #newworldorder #Whi…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['destroying'], -0.2, 0.0, None)])
# 2020-01-29 05:47:53 RT @t_danecki: When some #AntiWhite says he's white, implying he's OBJECTIVE, I point out that it is amazing that someone would BRAG that h…
# Sentiment(polarity=0.20000000000000004, subjectivity=0.3333333333333333, assessments=[(['white'], 0.0, 0.0, None), (['objective'], 0.0, 0.1, None), (['amazing'], 0.6000000000000001, 0.9, None)])
# 2020-01-29 05:30:40 RT @t_danecki: We're always being asked why do we need an exclusively white space.
#
# The QUESTION for any other race, would bring a person u…
# Sentiment(polarity=-0.0625, subjectivity=0.1875, assessments=[(['white'], 0.0, 0.0, None), (['other'], -0.125, 0.375, None)])
# 2020-01-29 05:08:00 So now you're justifying the #whitegenocide you are also saying isn't happening. Interesting https://t.co/jwjaALvOD1
# Sentiment(polarity=0.5, subjectivity=0.5, assessments=[(['interesting'], 0.5, 0.5, None)])
# 2020-01-29 05:07:52 @RayRahmanNYC @RodneyRecloose @AW_HateWatch So now you're justifying the #whitegenocide you are also saying isn't happening. Interesting
# Sentiment(polarity=0.5, subjectivity=0.5, assessments=[(['interesting'], 0.5, 0.5, None)])
# 2020-01-29 04:56:42 RT @t_danecki: If you love living in a brown country, pick one and STAY THERE.
#
# If you don't have a problem with white people o living in w…
# Sentiment(polarity=0.25, subjectivity=0.3, assessments=[(['love'], 0.5, 0.6, None), (['white'], 0.0, 0.0, None)])
# 2020-01-29 04:53:05 @cowcreekgeek “Diversity” is OFFICIAL POLICY not an accident and your charts don’t justify #WhiteGenocide https://t.co/3wJOYlDrzz
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-01-29 04:40:15 RT @RightStuff47: ANYTHING "too White" ALWAYS needs Diversity.
# Diversity means chasing down the last White Oscar winner.
# Diversity is a cod…
# Sentiment(polarity=-0.038888888888888896, subjectivity=0.08888888888888889, assessments=[(['white'], 0.0, 0.0, None), (['down'], -0.15555555555555559, 0.2888888888888889, None), (['last'], 0.0, 0.06666666666666667, None), (['white'], 0.0, 0.0, None)])
# 2020-01-29 04:39:49 RT @RightStuff47: Attacking our culture, history &amp; heroes is an integral part of #WhiteGenocide.
# #AntiWhites deny #WhiteGenocide, then trea…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-01-29 04:24:47 RT @RightStuff47: ANYTHING "too White" ALWAYS needs Diversity.
# Diversity means chasing down the last White Oscar winner.
# Diversity is a cod…
# Sentiment(polarity=-0.038888888888888896, subjectivity=0.08888888888888889, assessments=[(['white'], 0.0, 0.0, None), (['down'], -0.15555555555555559, 0.2888888888888889, None), (['last'], 0.0, 0.06666666666666667, None), (['white'], 0.0, 0.0, None)])
# 2020-01-29 04:16:38 RT @AW_HateWatch: #ProWhite BILLBOARDS that oppose #WhiteGenocide are CENSORED!
# #AntiWhite GOVERNORS and MAYORS say, "NO #FreeSpeech for #W…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-01-29 04:08:45 RT @t_danecki: When some #AntiWhite says he's white, implying he's OBJECTIVE, I point out that it is amazing that someone would BRAG that h…
# Sentiment(polarity=0.20000000000000004, subjectivity=0.3333333333333333, assessments=[(['white'], 0.0, 0.0, None), (['objective'], 0.0, 0.1, None), (['amazing'], 0.6000000000000001, 0.9, None)])
# 2020-01-29 03:57:13 RT @MinoritySave: @BasedPoland @Catherine_LCP Mass migration of Africans and Muslims is destroying Europe ‼️
#
# #Agenda21 #newworldorder #Whi…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['destroying'], -0.2, 0.0, None)])
# 2020-01-29 03:56:20 RT @MinoritySave: @BasedPoland @Catherine_LCP Mass migration of Africans and Muslims is destroying Europe ‼️
#
# #Agenda21 #newworldorder #Whi…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['destroying'], -0.2, 0.0, None)])
# 2020-01-29 03:46:41 RT @KeepitRealTea: #WhiteGenocide Extreme Paranoia
# a mental condition characterized by delusions of persecution, unwarranted  or exaggerate…
# Sentiment(polarity=-0.1125, subjectivity=0.6, assessments=[(['extreme'], -0.125, 1.0, None), (['mental'], -0.1, 0.2, None)])
# 2020-01-29 03:32:07 RT @RightStuff47: ANYTHING "too White" ALWAYS needs Diversity.
# Diversity means chasing down the last White Oscar winner.
# Diversity is a cod…
# Sentiment(polarity=-0.038888888888888896, subjectivity=0.08888888888888889, assessments=[(['white'], 0.0, 0.0, None), (['down'], -0.15555555555555559, 0.2888888888888889, None), (['last'], 0.0, 0.06666666666666667, None), (['white'], 0.0, 0.0, None)])
# 2020-01-29 03:18:41 RT @MinoritySave: @BasedPoland @Catherine_LCP Mass migration of Africans and Muslims is destroying Europe ‼️
#
# #Agenda21 #newworldorder #Whi…
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['destroying'], -0.2, 0.0, None)])
# 2020-01-29 03:11:01 @BasedPoland @Catherine_LCP Mass migration of Africans and Muslims is destroying Europe ‼️
#
# #Agenda21… https://t.co/8LqRXtzvML
# Sentiment(polarity=-0.2, subjectivity=0.0, assessments=[(['destroying'], -0.2, 0.0, None)])
# 2020-01-29 02:58:59 @ABC Once #WhiteGenocide happens nobody will know.
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-01-29 02:55:19 Is it a conspiracy when it’s on the UN website?  #WhiteGenocide @TwitchyTeam @michellemalkin #Tsunami @BasedPoland… https://t.co/RJiPhPCAdA
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-01-29 02:49:57 RT @StonehillBirch: White Americans, here are some of the religious groups &amp; agencies responsible for #TheGreatReplacement; by importing ho…
# Sentiment(polarity=0.06666666666666667, subjectivity=0.26666666666666666, assessments=[(['white'], 0.0, 0.0, None), (['religious'], 0.0, 0.25, None), (['responsible'], 0.2, 0.55, None)])
# 2020-01-29 02:49:14 RT @t_danecki: No forced "diversity"=no race war.
#
# #WhiteGenocide
# Sentiment(polarity=0.15000000000000002, subjectivity=0.2, assessments=[(['no', 'forced'], 0.15000000000000002, 0.2, None)])
# 2020-01-29 02:38:45 RT @EuropeanRevolt: Shoah'd (from Twitter) footage of White South Africans under threat of genocide  preparing for coming conflict. #AntiWh…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['white'], 0.0, 0.0, None)])
# 2020-01-29 02:15:28 RT @t_danecki: Asia for the Asians.
# Africa for the Africans.
#
# White countries for EVERYBODY, or you're a "fascist"!
#
# "Anti-fascist" is a co…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['white', '!'], 0.0, 0.0, None)])
# 2020-01-29 01:17:21 Whites are soon going to have to take on spokesmen, not spokesmen for protecting the border and a melting pot a  sp… https://t.co/WcdioyuRuL
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-01-29 01:06:34 Sharia Law will DOMINATE the world - according to these traitors
#
# #WhiteGenocide https://t.co/kvA4uxAW5M
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-01-29 00:58:12 Huh? Hell no, not me but my Islamic converted sister sure would! She married one!
#
# #WhiteGenocide https://t.co/CWlFOrv5sx
# Sentiment(polarity=0.46875, subjectivity=0.5694444444444444, assessments=[(['sure', '!'], 0.625, 0.8888888888888888, None), (['married', '!'], 0.3125, 0.25, None)])
# 2020-01-29 00:55:22 Me: 😮...fuckpigs?...NOT ME!
#
# #WhiteGenocide https://t.co/hIlnwiCWlv
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-01-29 00:50:13 Late term abortion because the baby is white? 🤦🏻‍♀️
#
# #WhiteGenocide https://t.co/24c3U3kat3
# Sentiment(polarity=-0.15, subjectivity=0.3, assessments=[(['late'], -0.3, 0.6, None), (['white'], 0.0, 0.0, None)])
# 2020-01-29 00:19:28 Who is making these “pro-Moslem men” memes?
#
# YUUCCCK
#
# Who wants to mingle with moon-worshippers? Not me that’s for… https://t.co/GYraZ8LpcS
# Sentiment(polarity=0.2, subjectivity=0.1, assessments=[(['wants'], 0.2, 0.1, None)])
# 2020-01-29 00:08:16 #WhiteGenocide - Christians doing this in public schools wouldn’t be tolerated and allowed but this is? https://t.co/LWCNws3Ylu
# Sentiment(polarity=0.0, subjectivity=0.06666666666666667, assessments=[(['public'], 0.0, 0.06666666666666667, None)])
# 2020-01-29 00:06:14 In #Cologne, 12% of the population are Moslems &amp; there are 25+ mosques.
# The fertility rate in Cologne is 1.26 for… https://t.co/aeCFvpb4U3
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-01-29 00:04:11 @erodaswift How does this make you feel?
#
# No sick, right?
#
# #WhiteGenocide https://t.co/DnzAvU8MZt
# Sentiment(polarity=0.3214285714285714, subjectivity=0.6964285714285714, assessments=[(['no', 'sick'], 0.35714285714285715, 0.8571428571428571, None), (['right'], 0.2857142857142857, 0.5357142857142857, None)])
# 2020-01-28 23:26:41 RT @RightStuff47: Attacking our culture, history &amp; heroes is an integral part of #WhiteGenocide.
# #AntiWhites deny #WhiteGenocide, then trea…
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[])
# 2020-01-28 22:38:01 RT @t_danecki: We're always being asked why do we need an exclusively white space.
#
# The QUESTION for any other race, would bring a person u…
# Sentiment(polarity=-0.0625, subjectivity=0.1875, assessments=[(['white'], 0.0, 0.0, None), (['other'], -0.125, 0.375, None)])
# 2020-01-28 22:35:46 WHO IS WORTHY TO WIELD THE SWORD?
# #RacialRepublic #ЯR #IdentityPoliticsForum #IPF
# #WhiteGenocide #AntiWhite… https://t.co/7EPoaFr3w7
# Sentiment(polarity=0.3333333333333333, subjectivity=1.0, assessments=[(['worthy'], 0.3333333333333333, 1.0, None)])
# 2020-01-28 22:35:33 ARE WHITE PEOPLE WORTHY OF LIFE?
# Are #WhitePeople worthy of life?
# #RacialRepublic #ЯR #IdentityPoliticsForum #IPF… https://t.co/VXsnf6BcIf
# Sentiment(polarity=0.2222222222222222, subjectivity=0.6666666666666666, assessments=[(['white'], 0.0, 0.0, None), (['worthy'], 0.3333333333333333, 1.0, None), (['worthy'], 0.3333333333333333, 1.0, None)])
# 2020-01-28 22:08:07 RT @FitzInfo: White Europeans—not "native" Indians—may have been in North America first. https://t.co/GFSlcUnlRz #Solutreans #KalergiPlan #…
# Sentiment(polarity=0.125, subjectivity=0.16666666666666666, assessments=[(['white'], 0.0, 0.0, None), (['first'], 0.25, 0.3333333333333333, None)])
# 2020-01-28 21:26:18 Asia for the Asians.
# Africa for the Africans.
#
# White countries for EVERYBODY, or you're a "fascist"!
#
# "Anti-fascist… https://t.co/zLoOznhBgu
# Sentiment(polarity=0.0, subjectivity=0.0, assessments=[(['white', '!'], 0.0, 0.0, None)])
# 2020-01-28 21:24:06 We're always being asked why do we need an exclusively white space.
#
# The QUESTION for any other race, would bring a… https://t.co/LZbLd2MVzm
# Sentiment(polarity=-0.0625, subjectivity=0.1875, assessments=[(['white'], 0.0, 0.0, None), (['other'], -0.125, 0.375, None)])
# 2020-01-28 21:20:31 When some #AntiWhite says he's white, implying he's OBJECTIVE, I point out that it is amazing that someone would BR… https://t.co/O6UzcUAjlS
# Sentiment(polarity=0.20000000000000004, subjectivity=0.3333333333333333, assessments=[(['white'], 0.0, 0.0, None), (['objective'], 0.0, 0.1, None), (['amazing'], 0.6000000000000001, 0.9, None)])
